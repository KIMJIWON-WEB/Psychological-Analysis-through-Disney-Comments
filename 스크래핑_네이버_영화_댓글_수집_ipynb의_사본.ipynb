# %% [markdown]
# <a href="https://colab.research.google.com/github/KIMJIWON-WEB/storybank/blob/main/%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91_%EB%84%A4%EC%9D%B4%EB%B2%84_%EC%98%81%ED%99%94_%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=161967
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %% [markdown]
# ## 맛보기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 161967 ## 기생충
total_count = 36754  ## 전체 크기=19,653

# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=219
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=220
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=221
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=222
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=223
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=224
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=225
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=226
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=227
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=228
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=229
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=230
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=231
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=232
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=233
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=234
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=235
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=236
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=237
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=238
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=239
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=240
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=241
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=242
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=243
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=244
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=245
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=246
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=247
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=248
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=249
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=250
# ...
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1884
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1885
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1886
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1887
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1888
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1889
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1890
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1891
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1892
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1893
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1894
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1895
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1896
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1897
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1898
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1899
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1900
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1901
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1902
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1903
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1904
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1905
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1906
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1907
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1908
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1909
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1910
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1911
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1912
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1913
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1914
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1915
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1916
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1917
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1918
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1919
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1920
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1921
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1922
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1923
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1924
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1925
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1926
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1927
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1928
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1929
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1930
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1931
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1932
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1933
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1934
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1935
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1936
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1937
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1938
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1939
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1940
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1941
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1942
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1943
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1944
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1945
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1946
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1947
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1948
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1949
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1950
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1951
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1952
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1953
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1954
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1955
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1956
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1957
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1958
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1959
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1960
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1961
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1962
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1963
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1964
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1965

# %% [markdown]
# ### 개별 리뷰 세부 사항

# %%
## 해당 페이지의 html FULL
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20201023150533" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20201023150533" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20201023150533" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20201023150533" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="107924"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# <input id="page" name="page" type="hidden" value="1"/>
# <div class="ifr_area basic_ifr">
# <div class="input_netizen ">
# <!-- [D] 관람객 평점 작성 완료 -->
# <div class="ly_viewer" id="actualPointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p>관람객 평점이 등록되었습니다.<br/><em>네이버페이 포인트 500원</em>이 적립되었습니다.<br/><em>7일 이후</em> 확인 가능합니다.</p>
# <p>(평점 삭제시, 적립된 포인트는 회수됩니다.)</p>
# <div class="btn">
# <a class="ok" href="#" id="actualPointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="actualPointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료 -->
# <!-- [D] 관람객 평점 작성 완료2 -->
# <div class="ly_viewer" id="pointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p class="msg1">관람객 평점이 등록되었습니다.</p>
# <div class="btn">
# <a class="ok" href="#" id="pointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="pointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료2 -->
# <div class="score_total">
# <strong class="total">관람객 평점 <em>19,674</em>건<button class="btn_review" id="open-form-btn">내 평점 등록</button></strong>
# </div>
# <div class="top_behavior" id="orderCheckbox">
# <ul class="sorting_list">
# <li class="on"><a href="#" onclick="parent.clickcr(this, 'ara.bysym', '', '', event); dislplayOrder('sympathyScore');">공감순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.byrct', '', '', event); dislplayOrder('newest');">최신순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.high', '', '', event); dislplayOrder('highest');">평점 높은 순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.low', '', '', event); dislplayOrder('lowest');">평점 낮은 순</a></li>
# </ul>
# <ul class="quarter_mode">
# <li>
# <input class="blind " id="spoilerYnCheckBox" name="spilerViewer" onclick="parent.clickcr(this,'','','',event); return false;" title="스포일러 보기" type="checkbox"/>
# <label class="label_viewer" for="spoilerYnCheckBox" id="spoilerYnLable">스포일러 보기</label>
# </li>
# <li>
# <input class="blind " id="actualYnCheckBox" name="viewer" onclick="parent.clickcr(this,'ura.mgs','','',event); return false;" title="관람객 평점만 보기" type="checkbox"/>
# <label class="label_viewer" for="actualYnCheckBox" id="actualYnLable">관람객 평점만 보기</label>
# <a class="help _actualPointHelp" href="#" id="actualPointHelpButton" title="도움말">관람객 평점만 보기 도움말</a>
# <div class="ly_help _actualPointHelp" id="actualPointHelp" style="display:none">
# <h5>관람객평점만 보기 안내 레이어</h5>
# <div class="ly_cont _actualPointHelp">
# <p>네이버 영화에서 예매하신 고객님들이<br/> 영화 관람 후 등록해주신 평점입니다.</p>
# </div>
# <button class="btn_close _actualPointHelp" id="actualPointHelpCloseButton" title="닫기" type="button"><span class="blind">관람객 평점만 보기 안내 레이어 닫기</span></button>
# <span class="arr _actualPointHelp"></span>
# </div>
# </li>
# </ul>
# </div>
# <div class="score_result">
# <ul>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8408649, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>lmj7****</span>
# </a>
# </em>
# <em>2014.01.22 00:33</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lmj7****', '3cGndlGu/ht4BrFD1iNcD+3uRuTBGne6R+AFKA3Rogg=', '첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추! ', '8408649', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8408649">4670</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8408649">574</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																심은경의 매력을 느낄수잇는영화~~
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409921, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>gudr****</span>
# </a>
# </em>
# <em>2014.01.22 12:07</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gudr****', 'Th6dVBrzvWiUx+glWWkbLR2/xmW8N/3x0iJ91F04ZyQ=', '심은경의 매력을 느낄수잇는영화~~ ', '8409921', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409921">4157</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409921">377</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																마지막에 여자환호성 듣는영화 입니다 ㅋㅋ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8414887, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>pak9****</span>
# </a>
# </em>
# <em>2014.01.23 09:49</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','pak9****', 'vMKkx6u2U24KWtwKT7Hgx1TLN/c1PiixVm5t6RmIPwk=', '마지막에 여자환호성 듣는영화 입니다 ㅋㅋ ', '8414887', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8414887">2919</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8414887">167</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:80.0%"></span></span><em>8</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																스토리는 2% 아쉬운감이 없지않아있는데, 배우들의 연기가 정말 좋습니다! 가족끼리 함께보기 좋은영화 :)
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8410149, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>enchanted(ench****)</span>
# </a>
# </em>
# <em>2014.01.22 13:08</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','ench****', 'D/bKm65Iro/1mEGjvK5U9askMKD4OqNt+rQu8lM2GJk=', '스토리는 2% 아쉬운감이 없지않아있는데, 배우들의 연기가 정말 좋습니다! 가족끼리 함께보기 좋은영화 :) ', '8410149', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8410149">2929</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8410149">534</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																마지막 장면을 잊을 수 없다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8411606, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>복부처(ming****)</span>
# </a>
# </em>
# <em>2014.01.22 18:11</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','ming****', 'QJJ+sik4OFdzDhxau23rM0yT6I9mvi4PYtOSYdSSG1c=', '마지막 장면을 잊을 수 없다 ', '8411606', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8411606">1599</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8411606">88</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																심은경을 위한 영화. 정말 심은경을 위해 만들어진 역할이라고 해야하나. 노래실력이며 개그감 넘치는 연기력 모두 최고였다. 무엇보다 최고는, 마지막 장면의 반전!!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8410187, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>thfx****</span>
# </a>
# </em>
# <em>2014.01.22 13:18</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','thfx****', 'LS05SctIqWA14ziNS069/gRP+bglldwGMMQ/9nFoyGs=', '심은경을 위한 영화. 정말 심은경을 위해 만들어진 역할이라고 해야하나. 노래실력이며 개그감 넘치는 연기력 모두 최고였다. 무엇보다 최고는, 마지막 장면의 반전!! ', '8410187', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8410187">1205</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8410187">88</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																심은경 최고. 왜 이렇게 웃기냐...연기 넘 잘 한다. 기분 좋은 영화!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409809, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>미도리(luna****)</span>
# </a>
# </em>
# <em>2014.01.22 11:24</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','luna****', 'yqn6E3Splwd9g+qg9fPL6VtQCPJusrJy0Il14eeEQ/A=', '심은경 최고. 왜 이렇게 웃기냐...연기 넘 잘 한다. 기분 좋은 영화! ', '8409809', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409809">994</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409809">75</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																평점8점대가뭐냐 9점이상짜리다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409952, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>wkdw****</span>
# </a>
# </em>
# <em>2014.01.22 12:14</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','wkdw****', 'xAu0nwVcpi48VAqTpTj/VNZI7oqzP3R0boV9WngnMus=', '평점8점대가뭐냐 9점이상짜리다 ', '8409952', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409952">1003</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409952">133</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_8">
#
#
#
# 																웃음과감동,두마리의토끼를다잡은가족영화
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409024, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>잘되는나(lh00****)</span>
# </a>
# </em>
# <em>2014.01.22 02:00</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lh00****', 'stueHIKT0+ti56DbQQNE7BgSmaIhY0lOCemnPP+2170=', '웃음과감동,두마리의토끼를다잡은가족영화 ', '8409024', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409024">821</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409024">113</strong>
# </a>
# </div>
# </li>
# <li class="last">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																정말 오랜만에 극장에서 육성으로 현실웃음 터졌었어요!!완전 꿀잼!!!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8408627, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>아라리요(zzon****)</span>
# </a>
# </em>
# <em>2014.01.22 00:29</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','zzon****', 'W6Jl+l0NHKoFfFR+JvvBaHU4+mv8z4/QzQRqR0HHCvs=', '정말 오랜만에 극장에서 육성으로 현실웃음 터졌었어요!!완전 꿀잼!!! ', '8408627', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8408627">543</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8408627">72</strong>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paging">
# <div>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span class="on">1</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>2</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>3</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=4" id="pagerTagAnchor4" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>4</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=5" id="pagerTagAnchor5" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>5</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=6" id="pagerTagAnchor6" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>6</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=7" id="pagerTagAnchor7" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>7</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=8" id="pagerTagAnchor8" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>8</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=9" id="pagerTagAnchor9" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>9</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=10" id="pagerTagAnchor10" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>10</span></a>
# <a class="pg_next" href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="다음"><em>다음</em></a>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# <form accept-charset="euc-kr" id="reportForm" method="POST" name="reportForm1"></form>
# <script type="text/javascript">
#
#
# if (false == false && "after" == "after" && false) {
# 	if (true && false) {
# 		jindo.$Element("pointWriteExecuteLayer").show();
# 	} else if (false && true) {
# 		jindo.$Element("actualPointWriteExecuteLayer").show();
# 	}
# }
#
# var oElActualPointWriteExecuteLayer = jindo.$Element("actualPointWriteExecuteLayer");
#
# if (oElActualPointWriteExecuteLayer != null && oElActualPointWriteExecuteLayer != "undefined") {
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# var oElPointWriteExecuteLayer = jindo.$Element("pointWriteExecuteLayer");
#
# if (oElPointWriteExecuteLayer != null && oElPointWriteExecuteLayer != "undefined") {
#
# 	jindo.$Element("pointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("pointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# jindo.$Fn(function () {
#
#   function checkboxHandlerFactory(isActualYn, isLabel) {
#     return function() {
#       var actualYnChecked = jindo.$("actualYnCheckBox").checked;
#       var spoilerYnChecked = jindo.$("spoilerYnCheckBox").checked;
#
#       // convert
#       actualYnChecked = (isActualYn && isLabel)? !actualYnChecked : actualYnChecked;
#       spoilerYnChecked = (!isActualYn && isLabel)? !spoilerYnChecked : spoilerYnChecked;
#
#       location.href = "/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&onlyActualPointYn=" + (actualYnChecked? "Y" : "N")  + "&onlySpoilerPointYn=" + (spoilerYnChecked? "Y" : "N") + "&order=sympathyScore";
#     };
#   }
#
#
# 	if (jindo.$("actualYnCheckBox") != null) {
# 		jindo.$Fn(checkboxHandlerFactory(true, false), this).attach(jindo.$("actualYnCheckBox"), 'click');
# 	}
#
# 	if (jindo.$("actualYnLable") != null) {
# 	    jindo.$Fn(checkboxHandlerFactory(true, true), this).attach(jindo.$("actualYnLable"), 'click');
# 	}
#
#
#     if (jindo.$("spoilerYnCheckBox") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, false), this).attach(jindo.$("spoilerYnCheckBox"), 'click');
#   }
#
#   if (jindo.$("spoilerYnLable") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, true), this).attach(jindo.$("spoilerYnLable"), 'click');
#   }
#
#
# 	if (jindo.$Element("actualPointHelp") != null && jindo.$Element("actualPointHelp") != "undefined") {
# 		actualPointHelpLayerToggle = function() {
# 			setTimeout( function() {
# 				if (document.activeElement != null) {
# 					var focusedEl = jindo.$Element(document.activeElement);
# 					if (focusedEl != null) {
# 						if ( !focusedEl.hasClass("_actualPointHelp") ) {
# 							 jindo.$Element("actualPointHelp").hide();
# 						}
# 					}
# 				}
# 			}, 100);
# 		};
#
# 		new jindo.LayerManager("actualPointHelp", {
# 			sCheckEvent : "click",
# 			nHideDelay : 0
# 		}).link(jindo.$("actualPointHelp"), jindo.$("actualPointHelpButton"));
#
# 		jindo.$Element("actualPointHelpButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
# 		jindo.$Element("actualPointHelpCloseButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
#
# 		var waelActualPointHelp = jindo.$ElementList('._actualPointHelp');
#
# 		jindo.$A(waelActualPointHelp.$value()).forEach(function(value, index, array) {
# 			jindo.$Fn(actualPointHelpLayerToggle, this).attach(value, "blur");
# 		});
# 	}
#
# 	parent.setParamForPointAfterList('N', 'sympathyScore', '1');
# 	parent.resizePointAfterListIframe(0);
#
# 	// 최소 높이 270px 지정
# 	var frameHeight = eval(jindo.$Document().scrollSize().height);
#
# 	parent.resizePointAfterListIframe(frameHeight);
# 	parent.isPointAfterListLoad = true;
#
#
#
#
#   var isCheckPointExist = false;
#   // TODO: fix below condition
#   if (false) {
#     if(jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function(e) {
#
#
#
# 		  if (true && false && isCheckPointExist == false) {
# 			parent.point.checkPointAfterExistAndMileageSubscriptionType();
# 		  }
# 		  isCheckPointExist = true;
# 		  parent.openPointWriteForm();
# 		});
#     }
#   } else {
#     if (jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function (e) {
# 		  common.checkLogin(false);
# 		});
#     }
#   }
#
#   var isHide = true;
#
#   if(jindo.$Element("eval-edit")) {
#     jindo.$Element("eval-edit").attach("click", function() {
# 		  var edit = jindo.$Element("ly-edit");
# 	  	isHide ? edit.show() : edit.hide();
#       	isHide = !isHide;
#     })
#   }
#   parent.resizePointAfterListIframeOnLoad();
# }, this).attach(this, 'load');
#
# var point = {
# 		checkLoginWithMessage : function(login, loginMessage, notLoginMessage) {
# 			if(login == false){
# 				if(confirm(message)){
# 					top.location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(top.location.href);
# 				}
# 				return false;
# 			}
# 			return true;
# 		},
#
#
# 		checkAlreadyPointAfterExist : function (nid) {
# 			var existPointType = "pointBefore";
#
# 			if (false == false) {
# 				var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistJson.nhn", {
# 			    	onload : function (oRes) {
# 			    		var resultCode = oRes.json().resultCode;
#
# 			    		if (resultCode == "error") {							// 서버 오류
# 			    			alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    			return false;
# 			    		} else {
# 			    			existPointType = oRes.json().existPointType;
# 			    			point.del(existPointType, nid);
# 			    		}
# 			    	},
# 					timeout : 5,
# 			    	onerror : function (oRes) {
# 			    		alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    		return false;
# 			    	},
# 			    	ontimeout : function (oRes) {
# 			    		alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
# 			    		return false;
# 			    	}
# 			    });
#
# 			    oAjax.request({
# 			    	"movieCode" : "107924",
# 			    	"isActualPoint" : "false"
# 			    });
# 			} else {
# 				point.del(existPointType, nid);
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var ajaxDeleteUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if ("after" == "after") {
# 				ajaxDeleteUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(ajaxDeleteUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return false;
# 			}
#
# 			top.location.href = '/movie/bi/mi/point.nhn?code=107924#pointAfterTab';
# 			top.location.reload(true);
# 		}
# };
#
# function dislplayOrder(order) {
# 	var url = "/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after";
#
# 	var onlyActualPointYnValue = jindo.$("onlyActualPointYn").value;
#   	var includeSpoilerYnValue = jindo.$("includeSpoilerYn").value;
#
# 	if (onlyActualPointYnValue != "") {
# 		url = url + "&onlyActualPointYn=" + onlyActualPointYnValue;
# 	}
#
# 	if (includeSpoilerYnValue != "") {
#       url = url + "&onlySpoilerPointYn=" + includeSpoilerYnValue;
#     }
#
# 	url = url + "&order=" + order;
#
# 	location.href = document.location.protocol + "//" + document.domain + url;
# }
#
# function showPointListByNid(nid, target){
# 	if (target == 'after') {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
# 	} else {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname_before&target=before&sword="+nid;
# 	}
# }
#
# function refreshPage() {
#
# 	top.location.href = '/movie/bi/mi/point.nhn?code=107924#pointAfterTab';
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
#     parent.resizePointAfterListIframeOnLoad();
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
#     parent.resizePointAfterListIframeOnLoad();
# }
#
#
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("107924", "after");
# </script>
# <script type="text/javascript">
#             jindo.$Fn(function() {
#                 try{ lcs_do(); } catch(e){}
#             }).attach(window, "pageshow");
# 		</script>
# </body>
# </html>

# %%
## 1번째 덧글 FULL
# /html/body/div/div/div[5]/ul/li[1] --> 1번째 덧글 전체
# /html/body/div/div/div[5]/ul/li[2] --> 2번째 덧글 전체

score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[0]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8408649, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>lmj7****</span>
# </a>
# </em>
# <em>2014.01.22 00:33</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lmj7****', '3cGndlGu/ht4BrFD1iNcD+3uRuTBGne6R+AFKA3Rogg=', '첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추! ', '8408649', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8408649">4670</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8408649">574</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[2]

## 2번째 덧글 FULL
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[1]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																심은경의 매력을 느낄수잇는영화~~
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409921, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>gudr****</span>
# </a>
# </em>
# <em>2014.01.22 12:07</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gudr****', 'Th6dVBrzvWiUx+glWWkbLR2/xmW8N/3x0iJ91F04ZyQ=', '심은경의 매력을 느낄수잇는영화~~ ', '8409921', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409921">4157</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409921">377</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용
review_text = lis[0].find('p').find('span').getText()
review_text
# Out:
# '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추! \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용 -- 부호 빼고 깨끗하게!
review_text = lis[0].find('p').find('span').getText().strip()
review_text
# Out:
# '첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추!'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[1]/em

## 평점 점수
score = lis[0].find('em').getText()
score
# Out:
# '10'

# %%
#/html/body/div/div/div[5]/ul/li[1]/div[3]/a[1]/strong --> 좋아요. 
# /html/body/div/div/div[5]/ul/li[1]/div[3]/a[2]/strong --> 싫어요

## 좋아요/싫어요 점수
like = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[0].getText()
dislike = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[1].getText()
like, dislike
# Out:
# ('4670', '574')

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[1]/a/span

## 덧글 작성자 닉네임
nickname = lis[0].findAll('a')[0].find('span').getText()
nickname
# Out:
# 'lmj7****'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[2]

from datetime import datetime
created_at = datetime.strptime(lis[0].find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
created_at
# Out:
# datetime.datetime(2014, 1, 22, 0, 33)

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 50163
total_count = 5800  ## 전체 크기=5851

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....
# 190 번째 페이지 parsing....
# 191 번째 페이지 parsing....
# 192 번째 페이지 parsing....
# 193 번째 페이지 parsing....
# 194 번째 페이지 parsing....
# 195 번째 페이지 parsing....
# 196 번째 페이지 parsing....
# 197 번째 페이지 parsing....
# 198 번째 페이지 parsing....
# 199 번째 페이지 parsing....
# 200 번째 페이지 parsing....
# 201 번째 페이지 parsing....
# 202 번째 페이지 parsing....
# 203 번째 페이지 parsing....
# 204 번째 페이지 parsing....
# 205 번째 페이지 parsing....
# 206 번째 페이지 parsing....
# 207 번째 페이지 parsing....
# 208 번째 페이지 parsing....
# 209 번째 페이지 parsing....
# 210 번째 페이지 parsing....
# 211 번째 페이지 parsing....
# 212 번째 페이지 parsing....
# 213 번째 페이지 parsing....
# 214 번째 페이지 parsing....
# 215 번째 페이지 parsing....
# 216 번째 페이지 parsing....
# 217 번째 페이지 parsing....
# 218 번째 페이지 parsing....
# 219 번째 페이지 parsing....
# 220 번째 페이지 parsing....
# 221 번째 페이지 parsing....
# 222 번째 페이지 parsing....
# 223 번째 페이지 parsing....
# 224 번째 페이지 parsing....
# 225 번째 페이지 parsing....
# 226 번째 페이지 parsing....
# 227 번째 페이지 parsing....
# 228 번째 페이지 parsing....
# 229 번째 페이지 parsing....
# 230 번째 페이지 parsing....
# 231 번째 페이지 parsing....
# 232 번째 페이지 parsing....
# 233 번째 페이지 parsing....
# 234 번째 페이지 parsing....
# 235 번째 페이지 parsing....
# 236 번째 페이지 parsing....
# 237 번째 페이지 parsing....
# 238 번째 페이지 parsing....
# 239 번째 페이지 parsing....
# 240 번째 페이지 parsing....
# 241 번째 페이지 parsing....
# 242 번째 페이지 parsing....
# 243 번째 페이지 parsing....
# 244 번째 페이지 parsing....
# 245 번째 페이지 parsing....
# 246 번째 페이지 parsing....
# 247 번째 페이지 parsing....
# 248 번째 페이지 parsing....
# 249 번째 페이지 parsing....
# 250 번째 페이지 parsing....
# 251 번째 페이지 parsing....
# 252 번째 페이지 parsing....
# 253 번째 페이지 parsing....
# 254 번째 페이지 parsing....
# 255 번째 페이지 parsing....
# 256 번째 페이지 parsing....
# 257 번째 페이지 parsing....
# 258 번째 페이지 parsing....
# 259 번째 페이지 parsing....
# 260 번째 페이지 parsing....
# 261 번째 페이지 parsing....
# 262 번째 페이지 parsing....
# 263 번째 페이지 parsing....
# 264 번째 페이지 parsing....
# 265 번째 페이지 parsing....
# 266 번째 페이지 parsing....
# 267 번째 페이지 parsing....
# 268 번째 페이지 parsing....
# 269 번째 페이지 parsing....
# 270 번째 페이지 parsing....
# 271 번째 페이지 parsing....
# 272 번째 페이지 parsing....
# 273 번째 페이지 parsing....
# 274 번째 페이지 parsing....
# 275 번째 페이지 parsing....
# 276 번째 페이지 parsing....
# 277 번째 페이지 parsing....
# 278 번째 페이지 parsing....
# 279 번째 페이지 parsing....
# 280 번째 페이지 parsing....
# 281 번째 페이지 parsing....
# 282 번째 페이지 parsing....
# 283 번째 페이지 parsing....
# 284 번째 페이지 parsing....
# 285 번째 페이지 parsing....
# 286 번째 페이지 parsing....
# 287 번째 페이지 parsing....
# 288 번째 페이지 parsing....
# 289 번째 페이지 parsing....
# 290 번째 페이지 parsing....
# 291 번째 페이지 parsing....
# 292 번째 페이지 parsing....
# 293 번째 페이지 parsing....
# 294 번째 페이지 parsing....
# 295 번째 페이지 parsing....
# 296 번째 페이지 parsing....
# 297 번째 페이지 parsing....
# 298 번째 페이지 parsing....
# 299 번째 페이지 parsing....
# 300 번째 페이지 parsing....
# 301 번째 페이지 parsing....
# 302 번째 페이지 parsing....
# 303 번째 페이지 parsing....
# 304 번째 페이지 parsing....
# 305 번째 페이지 parsing....
# 306 번째 페이지 parsing....
# 307 번째 페이지 parsing....
# 308 번째 페이지 parsing....
# 309 번째 페이지 parsing....
# 310 번째 페이지 parsing....
# 311 번째 페이지 parsing....
# 312 번째 페이지 parsing....
# 313 번째 페이지 parsing....
# 314 번째 페이지 parsing....
# 315 번째 페이지 parsing....
# 316 번째 페이지 parsing....
# 317 번째 페이지 parsing....
# 318 번째 페이지 parsing....
# 319 번째 페이지 parsing....
# 320 번째 페이지 parsing....
# 321 번째 페이지 parsing....
# 322 번째 페이지 parsing....
# 323 번째 페이지 parsing....
# 324 번째 페이지 parsing....
# 325 번째 페이지 parsing....
# 326 번째 페이지 parsing....
# 327 번째 페이지 parsing....
# 328 번째 페이지 parsing....
# 329 번째 페이지 parsing....
# 330 번째 페이지 parsing....
# 331 번째 페이지 parsing....
# 332 번째 페이지 parsing....
# 333 번째 페이지 parsing....
# 334 번째 페이지 parsing....
# 335 번째 페이지 parsing....
# 336 번째 페이지 parsing....
# 337 번째 페이지 parsing....
# 338 번째 페이지 parsing....
# 339 번째 페이지 parsing....
# 340 번째 페이지 parsing....
# 341 번째 페이지 parsing....
# 342 번째 페이지 parsing....
# 343 번째 페이지 parsing....
# 344 번째 페이지 parsing....
# 345 번째 페이지 parsing....
# 346 번째 페이지 parsing....
# 347 번째 페이지 parsing....
# 348 번째 페이지 parsing....
# 349 번째 페이지 parsing....
# 350 번째 페이지 parsing....
# 351 번째 페이지 parsing....
# 352 번째 페이지 parsing....
# 353 번째 페이지 parsing....
# 354 번째 페이지 parsing....
# 355 번째 페이지 parsing....
# 356 번째 페이지 parsing....
# 357 번째 페이지 parsing....
# 358 번째 페이지 parsing....
# 359 번째 페이지 parsing....
# 360 번째 페이지 parsing....
# 361 번째 페이지 parsing....
# 362 번째 페이지 parsing....
# 363 번째 페이지 parsing....
# 364 번째 페이지 parsing....
# 365 번째 페이지 parsing....
# 366 번째 페이지 parsing....
# 367 번째 페이지 parsing....
# 368 번째 페이지 parsing....
# 369 번째 페이지 parsing....
# 370 번째 페이지 parsing....
# 371 번째 페이지 parsing....
# 372 번째 페이지 parsing....
# 373 번째 페이지 parsing....
# 374 번째 페이지 parsing....
# 375 번째 페이지 parsing....
# 376 번째 페이지 parsing....
# 377 번째 페이지 parsing....
# 378 번째 페이지 parsing....
# 379 번째 페이지 parsing....
# 380 번째 페이지 parsing....
# 381 번째 페이지 parsing....
# 382 번째 페이지 parsing....
# 383 번째 페이지 parsing....
# 384 번째 페이지 parsing....
# 385 번째 페이지 parsing....
# 386 번째 페이지 parsing....
# 387 번째 페이지 parsing....
# 388 번째 페이지 parsing....
# 389 번째 페이지 parsing....
# 390 번째 페이지 parsing....
# 391 번째 페이지 parsing....
# 392 번째 페이지 parsing....
# 393 번째 페이지 parsing....
# 394 번째 페이지 parsing....
# 395 번째 페이지 parsing....
# 396 번째 페이지 parsing....
# 397 번째 페이지 parsing....
# 398 번째 페이지 parsing....
# 399 번째 페이지 parsing....
# 400 번째 페이지 parsing....
# 401 번째 페이지 parsing....
# 402 번째 페이지 parsing....
# 403 번째 페이지 parsing....
# 404 번째 페이지 parsing....
# 405 번째 페이지 parsing....
# 406 번째 페이지 parsing....
# 407 번째 페이지 parsing....
# 408 번째 페이지 parsing....
# 409 번째 페이지 parsing....
# 410 번째 페이지 parsing....
# 411 번째 페이지 parsing....
# 412 번째 페이지 parsing....
# 413 번째 페이지 parsing....
# 414 번째 페이지 parsing....
# 415 번째 페이지 parsing....
# 416 번째 페이지 parsing....
# 417 번째 페이지 parsing....
# 418 번째 페이지 parsing....
# 419 번째 페이지 parsing....
# 420 번째 페이지 parsing....
# 421 번째 페이지 parsing....
# 422 번째 페이지 parsing....
# 423 번째 페이지 parsing....
# 424 번째 페이지 parsing....
# 425 번째 페이지 parsing....
# 426 번째 페이지 parsing....
# 427 번째 페이지 parsing....
# 428 번째 페이지 parsing....
# 429 번째 페이지 parsing....
# 430 번째 페이지 parsing....
# 431 번째 페이지 parsing....
# 432 번째 페이지 parsing....
# 433 번째 페이지 parsing....
# 434 번째 페이지 parsing....
# 435 번째 페이지 parsing....
# 436 번째 페이지 parsing....
# 437 번째 페이지 parsing....
# 438 번째 페이지 parsing....
# 439 번째 페이지 parsing....
# 440 번째 페이지 parsing....
# 441 번째 페이지 parsing....
# 442 번째 페이지 parsing....
# 443 번째 페이지 parsing....
# 444 번째 페이지 parsing....
# 445 번째 페이지 parsing....
# 446 번째 페이지 parsing....
# 447 번째 페이지 parsing....
# 448 번째 페이지 parsing....
# 449 번째 페이지 parsing....
# 450 번째 페이지 parsing....
# 451 번째 페이지 parsing....
# 452 번째 페이지 parsing....
# 453 번째 페이지 parsing....
# 454 번째 페이지 parsing....
# 455 번째 페이지 parsing....
# 456 번째 페이지 parsing....
# 457 번째 페이지 parsing....
# 458 번째 페이지 parsing....
# 459 번째 페이지 parsing....
# 460 번째 페이지 parsing....
# 461 번째 페이지 parsing....
# 462 번째 페이지 parsing....
# 463 번째 페이지 parsing....
# 464 번째 페이지 parsing....
# 465 번째 페이지 parsing....
# 466 번째 페이지 parsing....
# 467 번째 페이지 parsing....
# 468 번째 페이지 parsing....
# 469 번째 페이지 parsing....
# 470 번째 페이지 parsing....
# 471 번째 페이지 parsing....
# 472 번째 페이지 parsing....
# 473 번째 페이지 parsing....
# 474 번째 페이지 parsing....
# 475 번째 페이지 parsing....
# 476 번째 페이지 parsing....
# 477 번째 페이지 parsing....
# 478 번째 페이지 parsing....
# 479 번째 페이지 parsing....
# 480 번째 페이지 parsing....
# 481 번째 페이지 parsing....
# 482 번째 페이지 parsing....
# 483 번째 페이지 parsing....
# 484 번째 페이지 parsing....
# 485 번째 페이지 parsing....
# 486 번째 페이지 parsing....
# 487 번째 페이지 parsing....
# 488 번째 페이지 parsing....
# 489 번째 페이지 parsing....
# 490 번째 페이지 parsing....
# 491 번째 페이지 parsing....
# 492 번째 페이지 parsing....
# 493 번째 페이지 parsing....
# 494 번째 페이지 parsing....
# 495 번째 페이지 parsing....
# 496 번째 페이지 parsing....
# 497 번째 페이지 parsing....
# 498 번째 페이지 parsing....
# 499 번째 페이지 parsing....
# 500 번째 페이지 parsing....
# 501 번째 페이지 parsing....
# 502 번째 페이지 parsing....
# 503 번째 페이지 parsing....
# 504 번째 페이지 parsing....
# 505 번째 페이지 parsing....
# 506 번째 페이지 parsing....
# 507 번째 페이지 parsing....
# 508 번째 페이지 parsing....
# 509 번째 페이지 parsing....
# 510 번째 페이지 parsing....
# 511 번째 페이지 parsing....
# 512 번째 페이지 parsing....
# 513 번째 페이지 parsing....
# 514 번째 페이지 parsing....
# 515 번째 페이지 parsing....
# 516 번째 페이지 parsing....
# 517 번째 페이지 parsing....
# 518 번째 페이지 parsing....
# 519 번째 페이지 parsing....
# 520 번째 페이지 parsing....
# 521 번째 페이지 parsing....
# 522 번째 페이지 parsing....
# 523 번째 페이지 parsing....
# 524 번째 페이지 parsing....
# 525 번째 페이지 parsing....
# 526 번째 페이지 parsing....
# 527 번째 페이지 parsing....
# 528 번째 페이지 parsing....
# 529 번째 페이지 parsing....
# 530 번째 페이지 parsing....
# 531 번째 페이지 parsing....
# 532 번째 페이지 parsing....
# 533 번째 페이지 parsing....
# 534 번째 페이지 parsing....
# 535 번째 페이지 parsing....
# 536 번째 페이지 parsing....
# 537 번째 페이지 parsing....
# 538 번째 페이지 parsing....
# 539 번째 페이지 parsing....
# 540 번째 페이지 parsing....
# 541 번째 페이지 parsing....
# 542 번째 페이지 parsing....
# 543 번째 페이지 parsing....
# 544 번째 페이지 parsing....
# 545 번째 페이지 parsing....
# 546 번째 페이지 parsing....
# 547 번째 페이지 parsing....
# 548 번째 페이지 parsing....
# 549 번째 페이지 parsing....
# 550 번째 페이지 parsing....
# 551 번째 페이지 parsing....
# 552 번째 페이지 parsing....
# 553 번째 페이지 parsing....
# 554 번째 페이지 parsing....
# 555 번째 페이지 parsing....
# 556 번째 페이지 parsing....
# 557 번째 페이지 parsing....
# 558 번째 페이지 parsing....
# 559 번째 페이지 parsing....
# 560 번째 페이지 parsing....
# 561 번째 페이지 parsing....
# 562 번째 페이지 parsing....
# 563 번째 페이지 parsing....
# 564 번째 페이지 parsing....
# 565 번째 페이지 parsing....
# 566 번째 페이지 parsing....
# 567 번째 페이지 parsing....
# 568 번째 페이지 parsing....
# 569 번째 페이지 parsing....
# 570 번째 페이지 parsing....
# 571 번째 페이지 parsing....
# 572 번째 페이지 parsing....
# 573 번째 페이지 parsing....
# 574 번째 페이지 parsing....
# 575 번째 페이지 parsing....
# 576 번째 페이지 parsing....
# 577 번째 페이지 parsing....
# 578 번째 페이지 parsing....
# 579 번째 페이지 parsing....
# 580 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['박해빈(phb5****)',
#   '왜 평점이 7점대지?이상하네',
#   '10',
#   '404',
#   '15',
#   datetime.datetime(2014, 5, 5, 14, 38),
#   0],
#  ['툴루즈(tull****)',
#   '기발한 상상력,,팀버튼 이기에 가능한영화,..',
#   '9',
#   '341',
#   '23',
#   datetime.datetime(2013, 8, 15, 16, 44),
#   0],
#  ['픽쳐콤(goms****)',
#   '재밌었어요~!',
#   '10',
#   '199',
#   '18',
#   datetime.datetime(2013, 6, 16, 21, 34),
#   0],
#  ['na010(na01****)',
#   '한 편의 동화 ♥',
#   '10',
#   '184',
#   '13',
#   datetime.datetime(2013, 8, 9, 19, 29),
#   0],
#  ['토이(ikeu****)',
#   'good',
#   '10',
#   '136',
#   '16',
#   datetime.datetime(2013, 7, 13, 4, 34),
#   0],
#  ['sony(gluv****)',
#   '조니 뎁의 색다른 분장을 보고싶어서 봤는데 정말 죽이더군요...기존에 알고있던 이상한 나라의 엘리스보다 한층 업그레이드 된 영화화였던 것 같아요...2016년에 개봉예정인 2편도 정말 기대되네요~~',
#   '10',
#   '122',
#   '5',
#   datetime.datetime(2014, 5, 2, 19, 9),
#   0],
#  ['타자왕(ieew****)',
#   '너무 재밌게 봐서 러닝타임이 너무 짧다고 느껴질 정도네요. 108분이 짧은 시간은 아니지만.',
#   '10',
#   '79',
#   '8',
#   datetime.datetime(2013, 12, 2, 1, 13),
#   0],
#  ['혜선뿡(tjrk****)',
#   '재밋음',
#   '10',
#   '78',
#   '8',
#   datetime.datetime(2013, 8, 9, 19, 46),
#   0],
#  ['최인영(dlsd****)',
#   '내가 마치 꿈을 꾼 듯한 느낌이 들게 만든 영화',
#   '10',
#   '67',
#   '2',
#   datetime.datetime(2014, 11, 2, 11, 13),
#   0],
#  ['현동2(ih19****)',
#   '정말정말 찐짜진짜 잼있었음',
#   '10',
#   '66',
#   '3',
#   datetime.datetime(2013, 12, 15, 1, 49),
#   0],
#  ['굳모테스(kimt****)',
#   '청소년판 동화책이다.',
#   '10',
#   '60',
#   '3',
#   datetime.datetime(2013, 12, 12, 22, 54),
#   0],
#  ['choo****',
#   "왜 기대이하라고 할까 이 영화는 '이상한나라의앨리스'라는걸 알고들 보는걸텐데",
#   '8',
#   '48',
#   '2',
#   datetime.datetime(2011, 10, 8, 1, 16),
#   0],
#  ['냥이(gu28****)',
#   '진짜재밌음ㅠㅠ조니뎁ㅠㅠ모자장수ㅠㅠㅠ앨리스도이쁘고ㅠㅠ',
#   '10',
#   '44',
#   '2',
#   datetime.datetime(2014, 12, 26, 14, 36),
#   0],
#  ['jjwy****',
#   '방금또봣는데또재밋다..모자장수랑결혼할뻔ㅋㅋㅋ',
#   '10',
#   '41',
#   '3',
#   datetime.datetime(2014, 12, 7, 16, 17),
#   0],
#  ['최기원(rldn****)',
#   '동화를 영화로 할줄이야. 팀 버튼이 가능한 영화인것 같다',
#   '10',
#   '35',
#   '2',
#   datetime.datetime(2014, 12, 26, 23, 11),
#   0],
#  ['황민정(wolf****)',
#   '왤케 별점이 낮은지 진짜 이해 안 가네요ㅠㅠㅠ',
#   '10',
#   '37',
#   '4',
#   datetime.datetime(2015, 8, 1, 1, 5),
#   0],
#  ['Amour de U(dubu****)',
#   '진짜 명작이다 내가 좋아하는 영화 중 하나',
#   '10',
#   '30',
#   '0',
#   datetime.datetime(2014, 12, 3, 20, 4),
#   0],
#  ['obli****',
#   '이게 할리우드 수익랭킹 10위임 참고로 다크나이트가 11위. 이상하리만큼 흥행에 성공한 영화',
#   '7',
#   '46',
#   '16',
#   datetime.datetime(2012, 5, 16, 4, 29),
#   0],
#  ['상산초옹(yjwd****)',
#   '자신의 실제 아내인  헬레나를 대두인 우스꽝스러운 붉은여왕으로 캐스팅한 것만 해도 팀버튼은 익살꾼이다. 옛날 보았던 이상한 나라의 엘리스와는 전혀 다른 팀버튼의 독특한 색깔이 재창조해 낸 이상한 나라의 앨리스. 나는...',
#   '10',
#   '26',
#   '1',
#   datetime.datetime(2012, 12, 4, 9, 30),
#   0],
#  ['금계국(25th****)',
#   '원작의 기발한 상상력이 팀 버튼 식으로 업그레이드또 앨리스가의 자아찾기를  통해 스토리에 교훈성까지 다 잡은 것 같다.한 편의 새로운 동화책을 본 것 같았다, 굿굿',
#   '10',
#   '23',
#   '0',
#   datetime.datetime(2014, 12, 18, 17, 27),
#   0],
#  ['노유진(viy1****)',
#   '정말 대단하고멋진영화다',
#   '10',
#   '26',
#   '3',
#   datetime.datetime(2014, 12, 28, 11, 51),
#   0],
#  ['한비(jsyy****)',
#   '너무좋아요이거또봐도안질리는매력',
#   '10',
#   '27',
#   '4',
#   datetime.datetime(2014, 9, 11, 19, 40),
#   0],
#  ['선남선녀(thdq****)',
#   '이토록 몽환적인 분위기에 취해라',
#   '8',
#   '22',
#   '0',
#   datetime.datetime(2015, 10, 2, 2, 34),
#   0],
#  ['dbs0****',
#   '모자장수 눈 화장쩌네...ㅋㅋ',
#   '10',
#   '19',
#   '0',
#   datetime.datetime(2012, 1, 28, 14, 52),
#   0],
#  ['ㅇㅅㅎ(sh10****)',
#   '나를 로그인하게 만든 영화.꿀잼',
#   '10',
#   '21',
#   '4',
#   datetime.datetime(2014, 10, 11, 20, 37),
#   0],
#  ['리리리(bria****)',
#   '입체적이고 재밌는 캐릭터 붉은 여왕 아무의 사랑도 못받고 사랑을 줄려고 해도 도망가는 사람들.. 끝에는 약간 측은했다..',
#   '8',
#   '18',
#   '2',
#   datetime.datetime(2017, 3, 19, 22, 24),
#   0],
#  ['qmfp****',
#   '가장 아름답고 꿈같은 영화',
#   '10',
#   '15',
#   '0',
#   datetime.datetime(2016, 1, 10, 9, 11),
#   0],
#  ['kerr****',
#   '앤 해서웨이의 연기가 눈에 들어오네요ㅋㅋ',
#   '10',
#   '15',
#   '0',
#   datetime.datetime(2015, 12, 13, 0, 58),
#   0],
#  ['꼬마니(kals****)',
#   '재밌었습니다!!!^0^)/ㅎㅎ',
#   '10',
#   '15',
#   '0',
#   datetime.datetime(2014, 12, 10, 21, 18),
#   0],
#  ['장메리(bear****)',
#   '진심 이상한나라의 앨리스 그자체',
#   '10',
#   '15',
#   '1',
#   datetime.datetime(2014, 12, 26, 20, 53),
#   0],
#  ['무an12(dbst****)',
#   '내 인생은 내가 결정한다는 앨리스의 대사가 주제를 잘 나타내준 것 같다. 다만 하얀 여왕과 빨간 여왕의 대립에서 예쁜 사람 = 착하다, 추한 사람 =나쁘다라는 고정관념에서 벗어나지 못한 듯',
#   '7',
#   '12',
#   '1',
#   datetime.datetime(2018, 1, 13, 7, 56),
#   0],
#  ['VEN(losa****)',
#   '재밌었어요 조니뎁이 모자장수역을 정말 잘살린듯.',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2017, 10, 7, 15, 42),
#   0],
#  ['솜사탕나무(rlaa****)',
#   '기존의 앨리스처럼 깨어나면 아무것도 남지않는 꿈이 아니라 성장을 다룬게 마음에 들었다. 초반부 앨리스는 자기가 뭘 원하는지 모르는데 후반부엔 결혼식을 파하고 아버지일에도 뛰어드는게 너무 좋았다. 개인적으로 후속작인 ...',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2018, 6, 12, 10, 51),
#   0],
#  ['6육몽이6(jieu****)',
#   '왜 나는 붉은 여왕이 그렇게도 안쓰러웠을까.. 붉은 여왕도 분명 속은 여리고 착한 사람같았는데 말이지. 모자장수 사형 때 주변인들의 분장을 알아채고 하는 대사가 너무 안타까웠다.. 그나저나ㅡ 조니뎁, 너무 매력적ㅠ...',
#   '8',
#   '8',
#   '0',
#   datetime.datetime(2017, 12, 27, 15, 47),
#   0],
#  ['리베리의진열장(wlsd****)',
#   '평점 왜이리 낮은거지 못해도 8.5는 되야할거같은데 엘리스 완전이쁘고 그냥 모든게 최고였음',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2017, 8, 19, 4, 44),
#   0],
#  ['봄가비(dldl****)',
#   '꿀잼인데 평점 왜케 낮음..거울나라의 앨리스보고 1편이 잘 기억안나서 다시 봣는데 핵꿀잼 평점낮아서 평점주러옴',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2016, 9, 10, 13, 54),
#   0],
#  ['령(dtb0****)',
#   '이상한 나라의 앨리스를 이렇게 해석할 수 있다니..과연 팀 버튼',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2015, 12, 27, 13, 26),
#   0],
#  ['찹살떡(mong****)',
#   '분위기가 대단했다 몽환적이고 동화라는 느낌이 물씬 풍기는 배경에 캐릭터도 개성이 뚜렸하고 모자장수 붉은여왕 등등 스토리진행이 아쉬웠고 주제가 중구난방인것 같은 느낌 앨리스의 성장 모자장수의 사랑? 붉은여왕의 권력욕 ...',
#   '9',
#   '8',
#   '0',
#   datetime.datetime(2015, 12, 21, 20, 36),
#   0],
#  ['규리y(elel****)',
#   '2기대됨 아 빨리 보고싶네 모자장수♡',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2015, 9, 5, 12, 28),
#   0],
#  ['하댕(sso0****)',
#   '팀 버튼 & 조니뎁 최고의 영화',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2015, 2, 15, 16, 57),
#   0],
#  ['잿빛하늘(mung****)',
#   '역시 팀버튼  죠니뎁..',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2014, 11, 26, 23, 8),
#   0],
#  ['노희주(aabb****)',
#   '참 재미있었습니다.ㅎㅎ',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2015, 12, 11, 1, 18),
#   0],
#  ['Ssss(bana****)',
#   '진짜 조니뎁 연기너무 잘해 ㅠㅠ',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2016, 11, 14, 4, 12),
#   0],
#  ['홍시폭죽(tw_7****)',
#   '나이가 있어서인지 붉은여왕이 안타깝게 느껴지네요.  하얀여왕은 은근 자기손에 피안묻힐려고 하는게 얄미웠고요.ㅋㅋ.  영상미랑 주인공들,  그리고 판타지적 아름다움은 무척 좋으나 스토리는 흑-백, 선-악,추함-아름다움...',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2020, 2, 5, 21, 33),
#   0],
#  ['vage(owo7****)',
#   '캐릭터들이 확실하게 개성있어 좋았다 특히 하트 여왕',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2017, 5, 28, 15, 15),
#   0],
#  ['쀼(dian****)',
#   '내인생영화!! 2편보고 1편다시봤는데 이해도더잘되고1편은 영상미가진짜이뻤고 하나도안지루했다면 2편은 내용이풍부해지고 교훈을주는 내용 이였음 붉은여왕이 불쌍해지는....ㅠ',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2016, 9, 14, 13, 44),
#   0],
#  ['NPC(sas6****)',
#   '와..이건 사랑입니다♡',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2015, 8, 19, 2, 11),
#   0],
#  ['올리브(tlql****)',
#   '역쉬~~~~팀버튼!!!믿고보는!!!다음작이 빨리 나왔으면!!!',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2014, 12, 14, 15, 44),
#   0],
#  ['pulsar(puls****)',
#   '가위손,배트맨2의 다크하면서도 독창적인 판타지를 생각하면 조금 아쉽기는 하지만 팀버튼 작품중 가장 재미있고 유쾌하게 본 영화 같다.',
#   '9',
#   '6',
#   '1',
#   datetime.datetime(2014, 1, 1, 18, 38),
#   0],
#  ['ajho****',
#   '아카데미 미술,의상 2개부문 수상할 정도로..대단했던 걸작임. 반지의 제왕이 남성계 판타지 탑이면 여성류 판타지 탑은 이작품임. 2010년 작품임에도 월드 10억불을 넘긴 흥행대작.. 영화는 이렇게 만들어야 한다. ...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 9, 15, 19, 1),
#   0],
#  ['쫄깃(gim0****)',
#   '이영화 재미있네~~!',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2016, 9, 7, 20, 16),
#   0],
#  ['아침이슬(rori****)',
#   '환상적인 작품!! 말이필요없어요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2015, 12, 23, 16, 8),
#   0],
#  ['디카프리썬(smle****)',
#   '상상력이 매우 좋아욯ㅎ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2015, 12, 13, 16, 55),
#   0],
#  ['StarD(rlaa****)',
#   '앤 해서웨이만 보고싶은 영화 다른 디즈니 실사를 보고 기대를 했는지 긴장감, 몰입도, 앨리스 역의 연기력.... 원래 앤 해서웨이가 앨리스 역이라 했었는데 화이트 퀸 찰떡이었지만.. 여주의 연기력이.. 표정이 원래 ...',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2020, 1, 8, 2, 50),
#   0],
#  ['윤달(wjdd****)',
#   '지루했음...그나마 하얀 여왕 빨간 여왕 보는 재미로 봤다...',
#   '7',
#   '3',
#   '0',
#   datetime.datetime(2019, 10, 13, 0, 15),
#   0],
#  ['이은서(ruby****)',
#   '어릴 때 보고 이상한 나라의 엘리스 특유의 그 몽환적이면서 이상한 분위기 되게 좋아했었는데...지금 봐도 너무 재밌음! 마지막에 엘리스가 현실세계 사람들한테 한마디씩 하는 장면이 기억에 남는다',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 8, 31, 2, 32),
#   0],
#  ['기여밍(yuha****)',
#   '이건 1년마다 한번씩 계속 봐도 재밌다',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 8, 15, 17, 49),
#   0],
#  ['아헤벨겨(kkc7****)',
#   '세계관은 잘 표현했으나 스토리가 아쉬운 영화',
#   '6',
#   '3',
#   '0',
#   datetime.datetime(2019, 6, 14, 0, 8),
#   0],
#  ['여행S2영화(hana****)',
#   '앨리스 미드 보다가 우연히 같이 보게 된건데 재미있음. 티비에서 재방도 많이해서 세네번은 본것 같은데 볼때마다 재미있게 봄',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2019, 4, 10, 13, 48),
#   0],
#  ['kang****',
#   '말이 필요없이 너무 너무 재밌음 평점 7인게 이해안간다. 판타지 좋아하는 나에겐 온니 원 영화',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 4, 7, 11, 18),
#   0],
#  ['새틀라이트(gimi****)',
#   '누가 평점테러 했나??? 왜 평점이 7점대지??? 적어도 8점 후반으로 나와야할 점수인데 되게 이상하네요 이렇게나 재밌는 영화를',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 2, 19, 23, 13),
#   0],
#  ['비밀(soon****)',
#   '그 시절의 꿈을 잊은 어른에게 -앨리스-',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 1, 11, 13, 0),
#   0],
#  ['해피니스(luck****)',
#   '미아 존예 조니뎁 존잘.',
#   '8',
#   '3',
#   '0',
#   datetime.datetime(2019, 1, 9, 0, 25),
#   0],
#  ['뽀록이(seun****)',
#   '평점이 8점 중반대는 되야 될 듯',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 12, 4, 13, 54),
#   0],
#  ['슈워제네거(joc3****)',
#   '제가 어렸을 때, 대전에서 살았었는데, 거기에서 이상한 나라의 앨리스를 비디오로 봤어요. 실사화가 아닌 장편 애니메이션이었어요. 제가 그 영화를 애니메이션으로 봤는데, 노래가 나오고 재미있게 봤거든요. 그런데 201...',
#   '8',
#   '3',
#   '0',
#   datetime.datetime(2018, 11, 12, 11, 13),
#   0],
#  ['kjc8****',
#   '재밌어서 아침 저녁 계속 본것같아요',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 10, 27, 12, 46),
#   0],
#  ['배고파(piyo****)',
#   '극강의 시각적인 아름다움',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 1, 26, 12, 25),
#   0],
#  ['윤정욱(jwjj****)',
#   '역시 믿고보는 팀버튼. 최고까지는 아니지만 아주 잘 만든 영화',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 1, 19, 0, 57),
#   0],
#  ['마가영(doma****)',
#   '재밋어요!! 영상미도 좋고 나름 감동도 있어요 ㅎㅎ',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2017, 8, 29, 19, 55),
#   0],
#  ['꽁냥이냐(teen****)',
#   '너무 좋아요ㅠㅠ저이거 다섯번인가 돌려본거같아요ㅠㅠ!!!연기도 다 잘하고 분위기도 너무 좋고..이거 재밌게 보신분들은  나니아연대기 시리즈로 다추천이용!!',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2016, 2, 9, 1, 33),
#   0],
#  ['anou****',
#   '상상력보소 지린다진짜',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2015, 10, 17, 14, 17),
#   0],
#  ['쩜쩜(asyu****)',
#   '동화나 판타지를 좋아한다면 예쁜 영상에 빠질꺼에요~특히 배우들이 너무 매력적입니다 전 3번봤어요ㅋ내용은 이상한 나라의 앨리스, 거울나라의 앨리스, 미국의 유명한 시를 섞어서 우리나라사람이 이해하기엔 조금 덜 재밌을꺼...',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2015, 6, 19, 8, 12),
#   0],
#  ['이름할꺼없네(carr****)',
#   '부실한 전개 정이 안가는 캐릭터들 여러모로 아쉬운 결말칭찬할 만한 부분은 영상미밖에 없다. 오히려 붉은 여왕이 더욱 짠하게 느껴진다. 길예르모 델 토로처럼 비극적인 메세지를 바라지는 않았지만 너무 아동용 영화로 마무...',
#   '6',
#   '4',
#   '1',
#   datetime.datetime(2020, 3, 31, 15, 16),
#   0],
#  ['ㅇ(himh****)',
#   '진짜 재미있었는데 그 앨리스 원적이랑은 조금 다른데 매력이',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2016, 1, 16, 23, 11),
#   0],
#  ['기곰천사(lsh5****)',
#   '상상력 하나만으로 10점.',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 10, 1, 7, 27),
#   0],
#  ['김나윤(naa1****)',
#   '너무좋았습니당  몇년전에 한번 보고 어제다시봤었는데 전에보지못했던것들도 보이고 기억에강렬하게남았어요 CG도괜찮고 스토리도 어떻게저렇게짤수있지 감탄하면서봤네요 호불호가갈리기는 하는것같지만 저는좋았어요~!',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 3, 21, 23, 43),
#   0],
#  ['송호영(toyw****)',
#   '분며, 호불호가 갈릴 영화이나, 독창성 면에서는 디즈니 역대 실사화 시리즈 중 단연 원탑.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 5, 19, 18, 50),
#   0],
#  ['djfm****',
#   '나는 자고일어나서 아침마다 불가능한 상상6가지를 한다....',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 5, 17, 16, 43),
#   0],
#  ['pix(pixa****)',
#   '팀 버튼과 조니 뎁의 인연에 괜한 흠집만 내버린 영화',
#   '6',
#   '2',
#   '0',
#   datetime.datetime(2020, 5, 14, 13, 55),
#   0],
#  ['뻐네너우유(gpdn****)',
#   '내 꿈 속도 이러했음 좋겠다. 원더랜드 속 영웅, 꿈에서만 가능할테니까. 그 꿈을 꾸게 된다면 현실로 돌아오고 싶지 않을지도..',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2020, 3, 3, 1, 17),
#   0],
#  ['김수정(rhea****)',
#   '진짜 재밌고 말로 표현할 수 없는 이 영화만의 느낌이 있어요ㅠ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 2, 8, 23, 7),
#   0],
#  ['윤현진(yhja****)',
#   '',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 2, 4, 1, 43),
#   0],
#  ['쿠티에르(cout****)',
#   '',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 10, 15, 13, 23),
#   0],
#  ['윤채(yunc****)',
#   '존잼임 진저ㅉ쟈로 ㄹㅇ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 8, 2, 14, 36),
#   0],
#  ['달코밋(moon****)',
#   '꺄앗 하얀여왕 존예구 팀버튼 늑힘 넘 잘난다ㅠㅠ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 7, 21, 0, 33),
#   0],
#  ['성가영(rkdu****)',
#   '화려한 외면때문에 깊은 내면은 제대로된 평가를 받지 못하는 느낌..  진짜 최고다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 7, 21, 0, 20),
#   0],
#  ['행복하당(jiog****)',
#   '개꿀잼 ㄹㅇ잘만들었다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 7, 13, 2, 45),
#   0],
#  ['hyejin(besm****)',
#   '좋아요 표현정말 잘 했어요!',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 6, 5, 9, 28),
#   0],
#  ['블루(by20****)',
#   '내 인생 최고의 모험영화 나도 내인생의 재버워키들을 용기있게 넘어가고싶다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 5, 6, 2, 3),
#   0],
#  ['운 LOVE(ddok****)',
#   '너무 재밌었습니다. 진짜 환상의 나라네요',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 4, 13, 20, 22),
#   0],
#  ['이지은(wj03****)',
#   '최고다ㅠㅠㅠㅠ 조니뎁 모자장수역 너무 찰떡....',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 3, 20, 22, 52),
#   0],
#  ['복만쌤(drea****)',
#   '이 영화가 왜 칠점대죠 말도 안됩니다, 재미잇어요 강추',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 11, 14, 1, 37),
#   0],
#  ['오예쓰(gksd****)',
#   '영상미..ㅠㅜ잊을 수 없는 영화',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 11, 6, 10, 19),
#   0],
#  ['차하늘(11ck****)',
#   '10번 넘게 봐도 새롭고 어린 아이로 돌아가는 느낌',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 10, 14, 22, 36),
#   0],
#  ['Amin(nues****)',
#   '앨리스의 이상한 나라의 시작',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 10, 9, 17, 37),
#   0],
#  ['오드섬(odd_****)',
#   '역시 끝내주게 환상적이다.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 10, 2, 1, 55),
#   0],
#  ['하이(jsy8****)',
#   '기괴하면서 상상력이 장난 아님. 평범 7점대는 절대 아니고 8점대 이상 급. 색감도 죽이고, 케릭터들이 나사들이 하나씩 빠져있는게 말 그대로 이상한 나라임 ㅋ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 9, 29, 9, 23),
#   0],
#  ['이병1느그흥1(smgo****)',
#   '맨날 상투적인 식상한 영화 조폭영화 도둑때려잡는 영화 도둑놈영화 애국마케팅영화 상팔년도 신파영화 등등 보다가 뭔가 쌈박한 영화 찾다가 본 영화인데 시간가는줄 모르고 봤다 ㅋㅋ러닝타임도 짧고 재밌게봤다 ㅋㅋ헬조선 식상...',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 8, 16, 2, 41),
#   0],
#  ['잔디K(dbeh****)',
#   '진짜 이런 판타지는 얼마든지 보고싶다... 너무 연기하는거 맘에들고 특히 모자장수가 너무 좋음...',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 7, 14, 17, 17),
#   0],
#  ['Sidzhwldwlddl(ihg6****)',
#   '팀버튼이 읽어주는 한 편의 동화, 토끼굴 속을 들어갔다 나온 듯한 기분. 자욱한 안개와 축축한 습기가 맴도는 공간, 빙글거리고 톡톡 굴러가는 캐릭터들이 어우러져 즐겁고도 이상한 나라. 시원한 엔딩으로 깨어나는 꿈 속...',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2018, 7, 2, 18, 24),
#   0],
#  ['천명(sueb****)',
#   '와시코브스카는 고전 전문 여배우인감',
#   '5',
#   '2',
#   '0',
#   datetime.datetime(2018, 5, 27, 22, 57),
#   0],
#  ['별의조각(joe1****)',
#   'cg는 자연스럽고 좋은데, 내용이 중간에 팍팍 건너뛰는 느낌.번역도 짜증나고.',
#   '5',
#   '2',
#   '0',
#   datetime.datetime(2018, 4, 27, 23, 24),
#   0],
#  ['동근쓰(woww****)',
#   '판타지 영화를 좋아하는 사람들은 꼭 보길',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2018, 1, 5, 13, 1),
#   0],
#  ['procolem(oasi****)',
#   '팀버튼의 다크 판타지는 뭐',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2017, 12, 31, 20, 4),
#   0],
#  ['뿡붕(mymo****)',
#   '조니뎁 팀버튼이 아니면 상상할 수 없는 영화',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 10, 27, 4, 50),
#   0],
#  ['이길화(lght****)',
#   '여태 봤던 영화 중 제일 즐겁게 봤다.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 8, 27, 4, 19),
#   0],
#  ['우리옹(gusn****)',
#   '정말 재밌다. 남녀노소 즐길수 있는 동화.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 8, 14, 2, 23),
#   0],
#  ['arar****',
#   '완전재미써요...판타지♥',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 7, 12, 11, 2),
#   0],
#  ['B2DO(joyo****)',
#   '캐릭터들이 던지는 메시지를 되새기며 많은 것들을 생각하게 되는 영화. 팀버튼의 영상미와 연출력은 보너스',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 7, 5, 1, 20),
#   0],
#  ['Fucku(jeon****)',
#   '내가 이상한나라에 온기분 조니뎁사랑해요',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 5, 21, 1, 23),
#   0],
#  ['KATC(huns****)',
#   '디즈니 애니메이션 앨리스가 더 나은 듯하네요.',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2017, 1, 23, 17, 32),
#   0],
#  ['Yolo(yena****)',
#   '잘만들었지만 전체라고 하기엔 뭔가 어두운 감이 있음..',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2016, 12, 15, 12, 24),
#   0],
#  ['현유진(msuj****)',
#   '보는 내내 즐복했어요~~~~',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2016, 11, 8, 23, 45),
#   0],
#  ['해적(mais****)',
#   '판타지영화는 역시 팀버튼',
#   '6',
#   '2',
#   '0',
#   datetime.datetime(2016, 11, 4, 3, 2),
#   0],
#  ['yana****',
#   '무난하다고 본다...',
#   '6',
#   '2',
#   '0',
#   datetime.datetime(2016, 10, 17, 9, 37),
#   0],
#  ['차칸남자(mien****)',
#   '조니뎁이 주인공인줄 알았는데 아니네 ㅎㅎ 영화는 볼만함~!!',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2016, 10, 2, 0, 46),
#   0],
#  ['맛난감자(rd72****)',
#   '상상력과 스토리텔링은 별개.',
#   '3',
#   '2',
#   '0',
#   datetime.datetime(2016, 9, 24, 16, 40),
#   0],
#  ['첼시(namj****)',
#   '화려했지만 재미는 없었다',
#   '6',
#   '2',
#   '0',
#   datetime.datetime(2016, 9, 19, 5, 1),
#   0],
#  ['비타(kdym****)',
#   '평이 좋지 않았는데 꽤 볼만하다. 팀감독 작품중 수작은 아니지만 평작이상은 된다고 봄',
#   '7',
#   '2',
#   '0',
#   datetime.datetime(2016, 9, 14, 20, 10),
#   0],
#  ['Danny Seong(whun****)',
#   '팀버튼이기 이상한 나라를 연출할 수 있는 특별한 영화. 스토리면은 좀 아쉬운 듯 하지만 그래도 이상한 나라를 모험하는데 있어서 이 영화만한 것은 없음~',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2016, 9, 14, 10, 14),
#   0],
#  ['yong12(towa****)',
#   '2편 거울나라의 앨리스를 보고 1편을 봤는데 2편이 더 재미있다. 두 편 다 스토리가 약간씩 부족하지만 2편이 좀  나으면서 눈도 더 즐거웠다^^',
#   '7',
#   '2',
#   '0',
#   datetime.datetime(2016, 9, 11, 13, 42),
#   0],
#  ['서연(yeda****)',
#   '한번 보게 된뒤로 인생영화 등극',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2016, 8, 21, 23, 38),
#   0],
#  ['옥타비아누스(rosu****)',
#   '신기하다고 해야하나 독특한 아니 개성있는 영화 묘하게 빠져든다',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2016, 7, 4, 18, 54),
#   0],
#  ['SilverBullet(ehdg****)',
#   '이게 7점대의 영화는 아닌거 같은데 나만 그런거임?',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2016, 5, 10, 22, 16),
#   0],
#  ['허쉬(bbom****)',
#   '말이 필요없다 2편은 대체 언제 나올까',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2016, 1, 26, 7, 30),
#   0],
#  ['rlaw****',
#   '영화 구성도 진짜 좋았고, CG도 좋았고 오랜만에 동화같은 영화봐서 진짜 좋았음',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2015, 12, 29, 21, 1),
#   0],
#  ['비모(jiya****)',
#   '흠도 없었고 괜찮았던 영화 8~9점대는 되야된다고 생각',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2015, 11, 24, 21, 56),
#   0],
#  ['간지녀kim(al24****)',
#   '초등학교 적 봤던영화인데도 아직도 생생하다 나에게 판타지가 무엇인지를 처음알려준영화이다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2015, 11, 11, 1, 57),
#   0],
#  ['나은내일(thin****)',
#   '감탄스럽고 환상적이고 사랑스런 동화',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2015, 10, 12, 20, 11),
#   0],
#  ['하이친구(ckdg****)',
#   '비틀쥬스나 크리스마스의 악몽처럼 광기를 거침없이 유쾌하게 표현하지않고 진지하게 표현한 팀버튼표 진지한 영화',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2015, 9, 30, 3, 2),
#   0],
#  ['xyz(tjdt****)',
#   '외국영화라 더 보고싶은 영화!!현실과는 다른 매력이 있어 빠져들게 하는 영화!!',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2015, 9, 25, 14, 55),
#   0],
#  ['썸머(hiky****)',
#   '겉보기엔 그냥 환타지고 알록달록한 영화지만 어딘가..우울하고 어둡고 오싹한 분위기가 확실히 느껴지는 팀버튼 영화들ㅎ 나이를 먹을수록 팀버튼 영화가 새로운 느낌으로 다가온다',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2015, 9, 24, 3, 59),
#   0],
#  ['limh****',
#   '동화에 기본틀을 두었지만..화려한 캐릭터와 배경만으로도 볼거리는 충분했고,  배역진들도 내노라하는 배우들이라 연기에 흠뻑빠져 보았던...',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2015, 9, 22, 19, 11),
#   0],
#  ['Ginger(craz****)',
#   '아 진짜 제 시간과 돈을 투자한게 1도 후회되지 않습니다 후후..평점이 7점대라니 말도 안 돼....ㅋ...아 진짜 짱',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2015, 9, 9, 17, 53),
#   0],
#  ['skdu****',
#   '난 참 팀버튼과 조니뎁이 좋다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2015, 8, 25, 10, 53),
#   0],
#  ['라티(pis7****)',
#   '이건 진짜 명작중의 명작임',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2015, 8, 16, 13, 44),
#   0],
#  ['로리어츠(rabb****)',
#   '그래픽부터 모자장수까지 쬰쭇',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2015, 7, 20, 3, 9),
#   0],
#  ['Tora(funn****)',
#   '처음 봤을때는 뭔가 우울하고 어둡다는 생각을 했는데 두번보니 이해되고 세번보니 네번 보고싶어짐',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2015, 3, 23, 14, 45),
#   0],
#  ['123(newl****)',
#   '기발하고 재미있다. ㅇㅇ',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2015, 3, 1, 23, 57),
#   0],
#  ['칙칙(urwi****)',
#   '팀버튼스러운 이상한 나라의 앨리스',
#   '6',
#   '3',
#   '1',
#   datetime.datetime(2017, 9, 26, 23, 51),
#   0],
#  ['rkde****',
#   '진짜 배경이나 캐릭터들도 다 맘에 듬',
#   '10',
#   '3',
#   '1',
#   datetime.datetime(2015, 3, 7, 14, 37),
#   0],
#  ['복숭아(rrna****)',
#   '왜 평점이 7점대지? 이상하네',
#   '5',
#   '4',
#   '2',
#   datetime.datetime(2015, 11, 1, 20, 0),
#   0],
#  ['HEI(za44****)',
#   '평점이 왤케 높지난이거 영화관에서 그때 처음으로 3d로 봤는데노잼이었던것 밖에 기억이안나는데진부한 스토리',
#   '1',
#   '6',
#   '4',
#   datetime.datetime(2016, 9, 2, 19, 54),
#   0],
#  ['llfo****',
#   '커졌다 작아졌다 하는 몸, 말하는 동물들, 유령 고양이. 이런 정도로 풍부한 상상력을 보여줬다고 박수받을 시대는 진작에 지났다. 상상력을 기대하고 본 영환데 그 상상력이 평이하니 영화 또한 평범하게 느껴질 수 밖에....',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2020, 10, 14, 2, 46),
#   0],
#  ['지희츄(wlgm****)',
#   '가족들끼리 심야영화로 본 기억이 남 ,, 내 인생 최고의 판타지영화임 ,,',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 8, 23, 21, 58),
#   0],
#  ['jjo(jjoe****)',
#   '색감도 예쁘고 스토리도 좋고 여러번 볼만한 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 8, 18, 17, 9),
#   0],
#  ['수현(sher****)', '', '10', '1', '0', datetime.datetime(2020, 6, 7, 9, 27), 0],
#  ['수완(suen****)',
#   '진짜 이상한 나라에 들어온 기분. 모자장수가 정말 대박이었음 하트여왕도',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 5, 22, 10, 57),
#   0],
#  ['구름(dsc6****)',
#   '',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2020, 5, 17, 22, 57),
#   0],
#  ['유예담(yeda****)',
#   '',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 5, 17, 17, 20),
#   0],
#  ['징커벨(wldn****)',
#   '',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 4, 27, 0, 53),
#   0],
#  ['서예원(dpdn****)',
#   '',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 4, 22, 2, 51),
#   0],
#  ['하정(maya****)',
#   '모자장수잘생기고 내가제일 좋아하는 체셔도예쁘당',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 4, 14, 23, 40),
#   0],
#  ['Whfl(eebe****)',
#   '아련한 모자장수가 자꾸 생각난다. 왜 팀버튼 작품만 보면 여운이 남는지...',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 3, 23, 17, 54),
#   0],
#  ['agg(agg0****)',
#   '',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 2, 24, 15, 10),
#   0],
#  ['김치맨(sohj****)',
#   '디자인은 역시 갓버튼',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2020, 2, 11, 20, 51),
#   0],
#  ['홍수연(hsy1****)',
#   '영상미 지렷가... 이래서 내가 팀 버튼 감독 영화를 좋아하지',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 2, 8, 7, 8),
#   0],
#  ['죠(park****)',
#   '책이나 애니메이션이 더 재밌다기억에 남는 노래도 없어서 아쉽다',
#   '4',
#   '1',
#   '0',
#   datetime.datetime(2020, 2, 4, 12, 38),
#   0],
#  ['엄소민(ruda****)',
#   '',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 1, 27, 3, 4),
#   0],
#  ['김예은(tymk****)',
#   '와 대박 인생영화 됬어요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2019, 11, 15, 19, 3),
#   0],
#  ['ㅁㄴㅁㄴㄴㄴ(vvvv****)',
#   '팀 버튼 감독스럽게 기발한 배경 표현과 색감 등이 좋았고, 앨리스 연기도 좋았는데 스토리 라인이 너무 아쉽다. . 동화스러운 느낌을 전혀 못살린..',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2019, 11, 6, 20, 30),
#   0],
#  ['셩(9438****)',
#   '진심 최고 ㅠ 5번은 봤음,, 너무너무 재밌는 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2019, 10, 5, 1, 59),
#   0],
#  ['고소미각(sexy****)',
#   '앤해서웨이 조니뎁 인성개판이라는데 남주옆 자리메인 여주마냥 저여자가 있네..참네ㅋ앨리스가 조니뎁 옆에 떠야하는거 아님?',
#   '2',
#   '1',
#   '0',
#   datetime.datetime(2019, 10, 3, 0, 25),
#   0],
#  ['X it(alfo****)',
#   '생각보다 재밌게 본것 같아요~~',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2019, 9, 30, 16, 45),
#   0],
#  ['달봉도령(busk****)',
#   '엘리스 컨셉의 판타지 영화  소설을 읽고 그 기준치가 높은 상태에서 본다면 감독임의로 바꾼 스토리에 실망을 할듯 하다 선과 악이 확실함 권선징악에 전사가 용을 해치우는 식상한 라인이 누군가에겐 저평가를 받을수도 .....',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2019, 5, 28, 1, 22),
#   0],
#  ['다애(kumd****)',
#   '진짜 잘 짜였다.... 아... 너무 좋았다... 분위기도, 스토리도... 나도 가능한 일 다섯 개, 그리고 내가 이루고 싶은 일 하나 떠올리면 앨리스처럼 내게있어서의 재버워키를 헤치울 수 있을 거 같다...',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2019, 5, 6, 20, 33),
#   0],
#  ['gg(whth****)',
#   '보고 또 보는 영화 분위기가 몽환적이고 연기력이 훌륭함 배역도 다 찰떡이고 환상임',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2019, 4, 27, 19, 6),
#   0],
#  ['산이(kais****)',
#   '동화를 볼땐 아이의눈으로봐라. 눈을 합리적인 수준과 비창의적생각으로 가득메우고보니까 재미가 없는것이다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2019, 4, 2, 10, 5),
#   0],
#  ['아미노봇(nari****)',
#   '연출이나 기법 배경은 훌륭그러나 스토리가 별로다왜 굳이 비싼배우 들여갔는지도 모르겠고 후반부분은 실망',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2019, 3, 21, 1, 49),
#   0],
#  ['빠숑(syon****)',
#   '8점은 넘어도 될 영화 2편 보고 보니 둘이 평점이 바뀐듯 2편은 쓰레긴데 1편은 볼만했다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2019, 3, 4, 2, 15),
#   0],
#  ['칼있으마(stro****)',
#   '너무 궁금 합니다 .  지금 이영화 40분 봤는데 너무 지루해요 .2시간짜린데 평점좋아서 보고싶었는데 한계를 느껴요 . 중후반부터는 재밌나요? 나머지시간 투자해도 될런지 ... 궁금합니다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2019, 2, 18, 20, 56),
#   0],
#  ['임정옥(johw****)',
#   '진짜 재밋어욬ㅋ 꼭보세요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2019, 1, 21, 13, 23),
#   0],
#  ['예감(tjdw****)',
#   '기기기기가가가가그브',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2019, 1, 1, 18, 39),
#   0],
#  ['ME(jiye****)',
#   '한번꼭봐야지했던영화',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2018, 11, 26, 8, 18),
#   0],
#  ['그로(rlfl****)',
#   '난 저 앨리스가 왜케 무섭냐 30살이넘었는데도..',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2018, 11, 25, 13, 51),
#   0],
#  ['Lucien carr(hoon****)',
#   '색채와 디자인에 영감을 주는영화,',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2018, 11, 11, 2, 36),
#   0],
#  ['기타신동(insa****)',
#   '★★★★명작★★★★',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 10, 24, 0, 21),
#   0],
#  ['김수민(kjs5****)',
#   '너무 감동있고 봐도 봐도 동심으로 돌아가게해주고 스트레스도 없애주는 마음에 안심이 꽉차게 하는 그런 감사한영화 ... 고마워요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 10, 23, 21, 1),
#   0],
#  ['브라우니(kamj****)',
#   '팀버튼이 느껴지다만다',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2018, 10, 1, 3, 36),
#   0],
#  ['깔깔(gonn****)',
#   '별 기대없이 봤는데 생각보다 재밌음',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 9, 25, 11, 33),
#   0],
#  ['최은서(fun4****)',
#   '역시 팀 버튼과 그의 뮤즈',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 9, 22, 17, 34),
#   0],
#  ['어부(tymp****)',
#   '주제가 있고 환상적이어서 좋음',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2018, 9, 22, 10, 19),
#   0],
#  ['김지수(rhcm****)',
#   '솔직히 유치할줄알았는데...전혀... 끝까지 몰입해서 봤다. 너무 재밌었음!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 9, 15, 12, 19),
#   0],
#  ['뽀메(sel5****)',
#   '재있옹~~어른을 위한동화 역시 팀버튼~♡   신비롭다~아름답다~놀랍다!!!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 9, 14, 2, 59),
#   0],
#  ['전창민(md10****)',
#   '영상미는 좋은 것 같아요 헤헤',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 31, 12, 33),
#   0],
#  ['교니(b208****)',
#   '후속작 부터 보고 전편보는 거라 느낌이 색다르네요',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 28, 18, 42),
#   0],
#  ['현지(714s****)',
#   '이건 진짜 너무 재미없다..,영상이 예뻐서 6점 줌',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 22, 0, 56),
#   0],
#  ['바빈스키(mesu****)',
#   '이정도 상상력은 팀버튼이 아니면 불가능',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 18, 1, 17),
#   0],
#  ['웅동(enoq****)',
#   '기괴한 나라의 색다른 앨리스',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 15, 15, 38),
#   0],
#  ['jom3****',
#   '판타지  영화치곤 기발하고 볼만한 영상이었습니다',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 13, 14, 55),
#   0],
#  ['권지은(kok1****)',
#   '동화같지만 유치하지 않고 아름다움재밌어요~!!!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 13, 13, 41),
#   0],
#  ['side****',
#   '팀버튼 특유의 기묘한 분위기는 좋은데 뭔가 매끄럽지 못한거같다',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 12, 15, 18),
#   0],
#  ['labrava(o_os****)',
#   '부붉은여왕 ㅠㅠㅠ힘내요ㅠㅠ',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 8, 0, 42),
#   0],
#  ['월(dldp****)',
#   '한편에 동화같은 재밌는 영화 :)',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 7, 16, 47),
#   0],
#  ['나난(jum3****)',
#   '앨리스 너무 멋있다!!!!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 7, 12, 39),
#   0],
#  ['리승언(lgw2****)',
#   '내 인생 최고의 판타지 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 8, 3, 22, 49),
#   0],
#  ['신수연(shin****)',
#   '색감이나 그래픽에서도 너무 좋았고 상상력 대박',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 31, 11, 23),
#   0],
#  ['이천사(lcg2****)',
#   '솔직히 8점후반대..',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 24, 10, 46),
#   0],
#  ['김규희(sas2****)',
#   '인생영화추천 합니다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 21, 12, 11),
#   0],
#  ['김규희(sas2****)',
#   '인생영화추천 합니다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 21, 12, 11),
#   0],
#  ['김규희(sas2****)',
#   '인생영화추천 합니다. 꼭 보세요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 21, 12, 11),
#   0],
#  ['스누피(ehde****)',
#   '앨리스는 굉장함을 다시 얻었다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 19, 11, 55),
#   0],
#  ['다클(cara****)',
#   '그냥 볼만했던거같네요',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 14, 14, 9),
#   0],
#  ['한라봉오렌지먹고싶다(dlal****)',
#   '킬링타임용으로 볼 만함. 근데 왜 형부 불륜난 건 계속 숨겨주지. 언니가 나이 더 먹으면 그 예쁨도 한물 갈텐데 빨리 네가 결혼하기 싫은 남자랑 결혼하라고 말해서jQuery2240717605943168037_1531...',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 10, 13, 45),
#   0],
#  ['chldbdus(youy****)',
#   '볼 때마다 기분이 좋아요!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 8, 12, 16),
#   0],
#  ['미늉기방탄(95bl****)',
#   '지금 보는데 정말 재밌네',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 7, 11, 2),
#   0],
#  ['Lucete(dlgk****)',
#   '디즈니의 교훈, 원작의 매력적인 스토리, 팀버튼의 연출.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 5, 21, 22),
#   0],
#  ['우기발(ukba****)',
#   '재밌읍니다 이상한나라',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 4, 15, 51),
#   0],
#  ['이이(moon****)',
#   '5번은 계속 본 영화. 유치하던 뭐던 상상력이건 영화 연출이건 정말 많이 노력한게 보인다..',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 7, 1, 16, 47),
#   0],
#  ['슬기(chlt****)',
#   '최고 .... 볼 때마다 심장이 두근 거려요 단언컨대 제 기준 핀타지 영화 중에 최고',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 6, 30, 19, 44),
#   0],
#  ['집게사장님(hkh8****)',
#   '매분, 매초를 소중하게 여기고 내가 사는 시간이 행복이란걸 아는게 중요하다고 말해주는 영화. 어릴땐 그저 신기한 모험이라고만 생각했는데, 굉장히 철학적인 대사가 많은 동화였네요. 뭐가 꿈이고, 뭐가 현실인지 묻는 모...',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 6, 30, 16, 40),
#   0],
#  ['든든(pled****)',
#   '2보다 재밌는데 1이 평점이 더 낮네요그래서 9점 줍니다 어디서 평점 테러 왔나보네요',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2018, 6, 30, 14, 40),
#   0],
#  ['고긍정(dbwl****)',
#   '아니 세상에 이런영화를 이제야보다니',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 6, 28, 22, 55),
#   0],
#  ['바나난나나(sue0****)',
#   '내 인생 최고의 영화. 다른 영화가 밋밋하게 느껴질 정도다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 6, 17, 16, 39),
#   0],
#  ['Chloe(xhak****)',
#   '나도 어렸을 땐 잠들기 전에 불가능한 일들을 상상하곤 했는데',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 6, 13, 10, 22),
#   0],
#  ['DragonStone(wony****)',
#   '엄청 재밌어여!다시보고다시봐도...',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 6, 10, 21, 45),
#   0],
#  ['이제동(king****)',
#   '아 엘리스 진짜 너무 이뽀ㅜㅜㅜ!!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 5, 27, 19, 2),
#   0],
#  ['chla****',
#   '역시 팀버튼..♡ 판타지영화의 거장.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 5, 27, 9, 56),
#   0],
#  ['매력꾼 두두(ldk9****)',
#   '팀 버튼은 기대를 저버리지 않았죠.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 4, 30, 23, 41),
#   0],
#  ['뉴욕미엘t(zard****)',
#   '특별한영화공부좋은착한모든 고등학교 때 수업시간엔=엘가장 아름다운 것은 어딘가에 있을 것 같아서 더 많은 시간을 보낼 것 같습니다 여팬드립니다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 4, 20, 11, 20),
#   0],
#  ['넥셔스이글(alsw****)',
#   '팀버튼만의 어두운 매력이 빠졌다',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2018, 3, 16, 22, 15),
#   0],
#  ['psy6****',
#   '화려한 판타지에 고퀄리티 cg까지. 깔끔한 가족영화',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2018, 3, 10, 23, 58),
#   0],
#  ['신혜원(hyew****)',
#   '한마디로 진짜 너무재밌다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 18, 1, 50),
#   0],
#  ['Azure(msh3****)',
#   '언제 봐도 좋은 영화. 추억을 떠올리게 한다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 13, 9, 38),
#   0],
#  ['침침이(kimm****)',
#   '진짜진짜 재밌어요 티비에서 구매하고 볼정도로 재밌어요 추천합니당 시간날떄 보세요! 거울나라앨리스도 재밌어요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 10, 19, 24),
#   0],
#  ['Gwen(sexy****)',
#   '다시 봐도 너무 좋아요~어쩌면 살아가다가 한번쯤 앨리스가 되는 상상을 할 정도로ㅎㅎㅎ사랑스러운 조니댑!!정말 멋진 동화속 같은 영화!!!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 9, 4, 6),
#   0],
#  ['one5****',
#   '4.5 (10자 제한)',
#   '4',
#   '1',
#   '0',
#   datetime.datetime(2018, 1, 30, 20, 38),
#   0],
#  ['정빈(wjdq****)',
#   '어쩌다 보게되었는데 재밌어요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 1, 17, 2, 44),
#   0],
#  ['CY(hsyi****)',
#   '앨리스가 커 서이상한 나라에 가다니..정말 놀라운 상상력인 것 같다 캐릭터 하나하나가 다 개성있고 매력있었다 또 붉은여왕의 모습과 모자장수, 쌍둥이를 아 주잘 표현해낸 것 같아 감탄이 절로 나온다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2017, 11, 22, 15, 13),
#   0],
#  ['백호(dyki****)',
#   '팀버튼는 이 때부터 이상한 판타지 세계를 만들었지...',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2017, 11, 19, 0, 37),
#   0],
#  ['Tightrope(sham****)',
#   '헬레나 본햄카터의 연기력을 보는것 만으로도 영화는 재미남.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2017, 10, 19, 15, 26),
#   0],
#  ['멍게(haed****)',
#   '어릴때 봤을땐 엔딩도 황당하고 정서가 안맞는다 생각했는데 한참지나 지금 다시보니 재밌었다.',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2017, 9, 10, 11, 40),
#   0],
#  ['후유코오리(rkdw****)',
#   '거울 나라를 먼저봐서 새롭게 보이는 게 있다.',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2017, 8, 26, 9, 11),
#   0],
#  ['다연(ekdu****)',
#   '왜 평점이 7점일까요?',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2017, 8, 1, 15, 59),
#   0],
#  ['타임로드(dleh****)',
#   '영화 속에 앨리스는 감독 팀버튼이 자신의 상상력을 과거,현재 그리고 미래에 대한 소망으로 비유한 것이 아닐까',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2017, 7, 27, 19, 22),
#   0],
#  ['이다인(ekdl****)',
#   '재미있고 흥미롭게 본 작품',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2017, 5, 7, 20, 43),
#   0],
#  ['민(alsg****)',
#   '왜 팀버튼이 판타지를 그리느냐에 대한 대답',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2017, 4, 10, 0, 32),
#   0],
#  ['빈의자(moon****)',
#   "팀버튼' ....이런 정석'도 좋고... 2탄으로  살벌 무시한  성인용 하나 더 만들면 재밌을 것 같은데...",
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2017, 3, 23, 23, 13),
#   0],
#  ['사민(moon****)',
#   '으쓱쿵짝 춤만 기억에 남네',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2017, 3, 12, 2, 25),
#   0],
#  ['MD7(godc****)',
#   '믿고 보는 팀 버튼____',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2017, 3, 11, 17, 9),
#   0],
#  ['kk_h****',
#   '화려해도 흥미롭지 않은 이상한나라',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2017, 3, 11, 5, 57),
#   0],
#  ['김성윤(capp****)',
#   '앨리스에 관심이 생겨서 우연히 영화를 보게 되었어요. 제가 영화를 적게 봐서인진 몰라도,  지금까지 본 영화 중 가장 저를 감동시켰습니다. 보고 바로 거울 세계까지 봤어요. 앨리스가 멋지다고 생각도 들었고 , 저로선...',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2017, 3, 3, 21, 35),
#   0],
#  ['메이(dldu****)',
#   '본지는 오래됐지만 그 당시에는 내가 본 영화 중에서 손꼽을 만큼 재미있었다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 12, 12, 6, 54),
#   0],
#  ['hww(hana****)',
#   '전 재밌게 봤습니다. 처음부터 몰입도도 너무 좋았고요',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 12, 4, 21, 15),
#   0],
#  ['텐백(ten_****)',
#   '동화나라 인지 아닌지 끝까지 긴장하면서 봄',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2016, 12, 1, 11, 27),
#   0],
#  ['김정민(mini****)',
#   '재밌네요 영웅물 안 좋아했었는데',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 30, 1, 11),
#   0],
#  ['슈퍼네버랜드인(supe****)',
#   '개인의 성장과 그 속에서의  느낄 수 있는 교훈과 감동이 있었구요 .상상력과 영상미는 덤 . 앨리스 책이 워낙 좋잖아요?ㅎ',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 26, 1, 47),
#   0],
#  ['안녕하세요(wown****)',
#   '개성은 있지만 힘은 없는',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 20, 23, 25),
#   0],
#  ['etou****',
#   '너무 재미있게 봤어요. Good!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 20, 0, 15),
#   0],
#  ['chri****',
#   '조니뎁의 미치광이지만 애절한 눈빛~',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 17, 3, 11),
#   0],
#  ['빙신만보면짖는개(dpat****)',
#   '목을베라~~~~이거만생각나네. .',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 16, 22, 22),
#   0],
#  ['tigr****',
#   '평점 왜이리 낮지... 아이들을 위한 영화가 아니라 어른들을 위한 영화임.. 저는 10점 만점에 10점!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 8, 3, 24),
#   0],
#  ['이도현(abcx****)',
#   '진짜  1편은  재밋게봣는데.... 감독 바뀌니까  영... 아니네요...',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 8, 0, 5),
#   0],
#  ['천재(xorm****)',
#   '정말 재밌어요 ㅋㅋㅋ  ^^',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 7, 13, 44),
#   0],
#  ['03(qaqa****)',
#   '상상력이 어디잇는거죠??',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 4, 3, 49),
#   0],
#  ['Caesar(jwbj****)',
#   '역시 팀버튼 영화라는 말이 나오게 한다. 그만의 특이한 상상력과 그로테스키하면서도 색채감있는 영화속 풍경들은 역시 독창적이기도 하다. 내용은 동화와 크게 다를게 없지만 꽤 흥미롭다.',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 11, 2, 0, 16),
#   0],
#  ['일지매(oong****)',
#   '정말 재미있게 봤어요~',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 31, 16, 45),
#   0],
#  ['현정(aeuh****)',
#   '말도안되는 꿈을 꾼 듯 한 영화, 또 더 말도안되는 꿈을 꾸게하는 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 29, 23, 20),
#   0],
#  ['AILEEN(aile****)',
#   'It is very good movie : )',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 28, 15, 35),
#   0],
#  ['chok****',
#   '뭔가재밌는느낌같은느낌',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 25, 5, 22),
#   0],
#  ['아로아(ecla****)',
#   '판타스틱한 동화를 잘 표현했네요..',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 23, 17, 46),
#   0],
#  ['사르가스(tkfn****)',
#   '영상미도 좋았고, 지루함 전혀 없이 몰입도도 좋았고, 한마디로 말하면 재미있게 본 영화입니다! 여운이 남네요! 마치 판타지 동화책 한 권 읽는 듯했습니다!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 22, 22, 9),
#   0],
#  ['사자개(xyan****)',
#   '팀버튼과 이상한 나라의 앨리스가 만났는데 겨우 이 정도인가? 아쉬움과 실망감만 남기는 영화. 게임 맥기의 앨리스나 앨리스 매드니스 리턴즈가 물론 매우 뛰어나긴 하지만 그 작품들보다 아쉬운 레벨의 영화. 전체관람가의 ...',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 20, 16, 36),
#   0],
#  ['gaha****',
#   '평점 올려요~ 2010년에나온영화가 이정도',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 20, 14, 30),
#   0],
#  ['세젤귀유댕(kpg3****)',
#   '재미는 그닥... 뭔가 보고 아쉽다는 생각이 많이 드는 영화',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 20, 13, 25),
#   0],
#  ['ONE(acec****)',
#   '아니 이게 왜 점수가 7점? 상당히 멋지게 봤는데.',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 18, 4, 0),
#   0],
#  ['김세호(gim9****)',
#   '어렸을적 꾸던 꿈속나라 여행하고 돌아온 기분!! 이 시리즈 사랑함 ♥',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 17, 21, 42),
#   0],
#  ['모노레일(mono****)',
#   '이건 팀버튼이 아니야..',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 16, 16, 3),
#   0],
#  ['렌드(rien****)',
#   '인생 영화 중 하나 캐릭터들 매력이 엄청납니다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 15, 23, 47),
#   0],
#  ['밍(ming****)',
#   '재미남 빨리 후속작 보고싶다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 13, 3, 53),
#   0],
#  ['akih****',
#   '좋은데...충분히 신선했음 어린이 영화같지도 않고',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 11, 16, 44),
#   0],
#  ['cool****',
#   '아이들에겐 어렵고 어른들에겐 유치한 어정쩡한 영화',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 11, 14, 36),
#   0],
#  ['니츄(hlhl****)',
#   '볼거리는 많았으나 노잼....',
#   '3',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 8, 14, 28),
#   0],
#  ['토정(mdem****)',
#   '난 좋았다... 이런 분위기 참 좋아',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 8, 0, 58),
#   0],
#  ['영화평론가(kjon****)',
#   '우선 이런 영화는 팀버튼과 디즈니 헐리웃이 아니면 말들수 없다 스토리가 미흡하긴 해도 이런 판타지 영화를 만드는건 정말 힘듬',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 6, 2, 51),
#   0],
#  ['싱맨(kiri****)',
#   '나 다운 것을 찾는 것. 남이 정해 놓은 틀에 맞추지 않고 자신이 개척해 나가는 것. 엘리스 다운 것.',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 3, 16, 30),
#   0],
#  ['응니니(zoah****)',
#   '제밌음 ~ 마지막장면도 여운남고',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 3, 9, 7),
#   0],
#  ['꽃비(teso****)',
#   '미친 모자장수 멋져요♡',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 3, 4, 33),
#   0],
#  ['PAC(wowx****)',
#   '역시 팀버튼!! 영상미, 분위기, 음악 모든게 다 마음에 들었다! 상상력 정말 짱!!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 2, 17, 50),
#   0],
#  ['재규어(popy****)',
#   '팀 작품들 중 내겐 최고...!',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 2, 16, 37),
#   0],
#  ['shoo****',
#   '너무 좋다 이런영화 ㅜㅠ',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 2, 16, 27),
#   0],
#  ['엑스(deff****)',
#   '역시 팀 버튼이라는 말 밖에 동화속을 완벽하게 영상화 처음부터 끝까지 화면이 너무 아름답다',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 1, 20, 59),
#   0],
#  ['신원호(yofo****)',
#   '왜 앤 해서웨이 얘기는 안보이지 ㅋㅋ너무 매력적이던데 기대이상으로 꿀잼이였다 역시 조니뎁 엘리스도이쁘고 ㅋㅋ',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 10, 1, 20, 51),
#   0],
#  ['Nam Jiho(alks****)',
#   '팀버튼 다운 색감. 그러나 팀버튼 답지 종장. 그리고 디즈니 스러운 결말. 종장에서 깽판 친 것 빼곤 너무나 아름다운 영화였다.',
#   '4',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 30, 20, 32),
#   0],
#  ['무관심대마왕(dlrw****)',
#   '거울나라 앨리스가 나와서 찾아서 봤는데 2편 보다 1편이 더 재밌네요 ㅎㅎ 2편보다 6년 전인데도 cg도 괜찮고 어른도 보기 괜찮은 동화',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 29, 7, 24),
#   0],
#  ['해피맘(ju22****)',
#   '영화재밌다   난  조니뎁때문에 점수준다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 26, 22, 3),
#   0],
#  ['AA(anoi****)',
#   '아직까지도 생각나는 최고의 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 24, 19, 44),
#   0],
#  ['김수연(sooy****)',
#   '언제나 사랑스러운 나의 인생영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 24, 15, 27),
#   0],
#  ['dud3057(wndu****)',
#   '10번봐도질리지않는영화 붉은여왕못됬지만먼가웃김',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 22, 23, 12),
#   0],
#  ['A봉잉(doqh****)',
#   'ㄱ굴잼이에용우우유우',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 16, 20, 55),
#   0],
#  ['달님(ekfq****)',
#   '이상한 나라를 시각적으로 놀랍게 구현했다 팀버튼식의 이상한 나라는 환상적',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 11, 2, 58),
#   0],
#  ['명마스터(smc7****)',
#   '과도한 cg에도 불구하고 어색함 없는 영상미. 이걸로도 충분하다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 11, 0, 58),
#   0],
#  ['전(dhst****)',
#   '너무 좋아요♡ 시간 가는 줄 모르고 봤어요!!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 7, 15, 50),
#   0],
#  ['이경규(dlru****)',
#   '추억속 동화   볼만한작품',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 6, 23, 14),
#   0],
#  ['best****',
#   '평점이이것뿐이안돼세계적으로흥행한영화치고는너무낮어 붉은여왕 이최고 매력',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 4, 22, 22),
#   0],
#  ['jiny****',
#   '마지막에 영화 끝나고 흘러나오는 노래가 되게 좋았어요.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 9, 4, 10, 59),
#   0],
#  ['앤썸(pkh0****)',
#   '다른 동화영화들에 비해서 점수를 줬다',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2016, 8, 28, 22, 26),
#   0],
#  ['husky(infi****)',
#   'CG 는 훌륭했지만 줄거리는 살짝 심심했어요',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2016, 8, 15, 1, 17),
#   0],
#  ['핸(jhin****)',
#   '정말로재미있어요강추',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 8, 9, 15, 17),
#   0],
#  ['올리비아(jieu****)',
#   '평점 왜케 낮아? 9점주려했는데 평점낮아서 10점으로. 붉은 여왕 대두지만 넘 매력적임 2편에서는 더 많이 볼 수 있었으면~~붉은 여왕없으면 망할 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 8, 7, 1, 32),
#   0],
#  ['민디mindy(tlfz****)',
#   '앨리스 무척 당찬 아가씨인 것..! 디즈니+팀 버튼 환상이다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 7, 27, 1, 40),
#   0],
#  ['수아(sua4****)',
#   '판타지물 중에서도 제일 좋아하는 영화고 진짜 10번 넘게 다시봤다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 7, 15, 19, 43),
#   0],
#  ['다경(sdk5****)',
#   '팀버튼+조니뎁 조합은 사랑입니다♥스토리도 좋고 앨리스가 입은 드레스들 진짜 다 예쁨!!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 7, 12, 14, 47),
#   0],
#  ['주유(hajr****)',
#   '비쥬얼이랑 상상력은 인정',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2016, 7, 12, 2, 49),
#   0],
#  ['은봄(lucy****)',
#   '또봐도  질리지 않는 영화 지루한 부분도 없고 연기도 다들 잘한거같다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 7, 4, 15, 34),
#   0],
#  ['단풍노을(girl****)',
#   '어딘가 모르게 묘하고 야릇하게 끌렸었던 이 동화 특유의 그 이중성을,화려하게, 또 파격적이고도 완벽하게,그리고 내 상상 그 이상의 기대치로 표현한,정말 내 인생 최고의 작품이라 단언할 수 있다..!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 7, 3, 22, 23),
#   0],
#  ['밍(ys00****)',
#   '왜 평점이 7점대지.. 너무 재밌었음',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 6, 26, 16, 0),
#   0],
#  ['마시마로(djs1****)',
#   '상상력이 엄청나야 만들 수 있는 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 6, 14, 22, 9),
#   0],
#  ['라틴코릿(wake****)',
#   '재미지게 본영영    화 화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 5, 28, 10, 27),
#   0],
#  ['빵상연구학자(byun****)',
#   '책속에 다녀간느낌 심장이 뛴다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 5, 3, 17, 21),
#   0],
#  ['슐리(heea****)',
#   '인생영화로 남음 ㅠㅠ 진짜.. 한 3번넘게 본것같은데  믿고보는 팀버튼감독 영화.... 진짜 너무 좋다  앨리스가 너무 이쁨',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2016, 5, 2, 22, 33),
#   0],
#  ['부엉(ppqq****)',
#   '요냔이랑 요냔 아부지가 영국 제국주의의 원인이렸다',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2016, 3, 30, 9, 19),
#   0],
#  ['쉐이크쇼(meko****)',
#   '팀 버튼 작품답게 영상미와 분위기에 묘한 매력이 있긴하지만 영화자체는 내 취향이 아니더라',
#   '6',
#   '1',
#   '0',
#   datetime.datetime(2016, 3, 8, 1, 56),
#   0],
#  ['서영(2tjd****)',
#   '난 재밌었는데 평점이 좀 낮네^^....',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2016, 1, 28, 16, 47),
#   0],
#  ['ㅇ(hist****)',
#   '잘봤습니다~~~~짱짱',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 11, 26, 15, 12),
#   0],
#  ['레몬앨리스(kske****)',
#   '앨리스사랑해여어ㅓ어ㅓㅜㅜ',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 10, 7, 1, 24),
#   0],
#  ['요정지혜(sang****)',
#   '어릴적 동심으로 돌아간 기분 좋았다',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2015, 6, 21, 8, 44),
#   0],
#  ['셧업(5eot****)',
#   '믿고보는 팀버튼 감독!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 6, 9, 23, 37),
#   0],
#  ['jsyeon(jsye****)',
#   '젤 좋아하는 영화!!! 진짜 강추 !!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 6, 1, 22, 14),
#   0],
#  ['룰루(kny3****)',
#   '환상의 세계로 빠지기에 딱 좋은 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 5, 24, 19, 44),
#   0],
#  ['난나야(nhki****)',
#   '팀버튼 짱짱인듯....',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 5, 20, 22, 11),
#   0],
#  ['붕붕카(mols****)',
#   '재밌긴 재밌는데  스토리 전개방식이나 연출도 좀 진부했다',
#   '5',
#   '1',
#   '0',
#   datetime.datetime(2015, 5, 8, 7, 57),
#   0],
#  ['나(eun3****)',
#   '굳굳. 상상력이 쩔어줌.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 4, 19, 19, 44),
#   0],
#  ['보늬(jmch****)',
#   "10점짜린 아닌 것 같지만 평점이 너무 낮아서 10점 주고 본다. 팀버튼만의 색깔이 그대로 드러나 시각적으로 재미가 빠질 수없었지만' 여전사가 된 앨리스'는 보다 줄거리에 대해 설명이 부족한 것 같다....",
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 3, 20, 1, 58),
#   0],
#  ['죽마도(jhha****)',
#   '팀 버튼이란 이름이 주는 기대감에는 못 미치지만 나름 ㄱㅊ',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2015, 3, 6, 17, 57),
#   0],
#  ['첵흐(wl05****)',
#   '....♡왜 7점대지',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2015, 2, 28, 0, 44),
#   0],
#  ['명태(xodu****)',
#   '스토리가 좋다는 생각은 들지않지만 재미있게는 본 영화',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2015, 2, 26, 20, 26),
#   0],
#  ['푸른하늘(holl****)',
#   '정말 재밌는 판타지 동화네요 ㅋㅋ 캐릭터중에 마녀가 정말 웃김 ㅋㅋ 진짜 개성있네',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2015, 2, 20, 11, 11),
#   0],
#  ['인더시티(ctns****)',
#   'our fantasy already faded out away in this country',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2014, 12, 22, 0, 52),
#   0],
#  ['hwa5****',
#   '완전재밌음 이런영화가많이나왔으면',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2014, 12, 3, 15, 21),
#   0],
#  ['바부띵구(ddin****)',
#   '여주인공이 진짜 나이도 많아 보이는 미스캐스팅. 애니메이션이 100배는 더 낫다. 앨리스 매력이 하나도 없고~그냥 실사화 한거 영상미 정도 때문에 별 1개 더 준다. 매드 헤더는 그냥 애니에선 정신나간 약빤 단역에 ...',
#   '2',
#   '2',
#   '1',
#   datetime.datetime(2020, 1, 12, 23, 7),
#   0],
#  ['맨유(vkav****)',
#   '지루하다.',
#   '6',
#   '2',
#   '1',
#   datetime.datetime(2019, 10, 4, 23, 19),
#   0],
#  ['wltj****',
#   '상상력이 풍부해지는 영화다 동화같이 색감도 너무 예쁘다',
#   '10',
#   '2',
#   '1',
#   datetime.datetime(2018, 1, 26, 13, 22),
#   0],
#  ['깜보바보(hybr****)',
#   '마아....이이카나',
#   '6',
#   '2',
#   '1',
#   datetime.datetime(2017, 8, 19, 2, 58),
#   0],
#  ['하늘높이(good****)',
#   '벌써 4번째 보는 영환데 볼 때마다 새롭네여',
#   '10',
#   '2',
#   '1',
#   datetime.datetime(2015, 12, 6, 1, 2),
#   0],
#  ['Lucia(alsg****)',
#   '그럭저럭 킬링타임으로 볼만해요그치만 마음 깊이 남는 내용은 없는듯!',
#   '7',
#   '2',
#   '1',
#   datetime.datetime(2015, 8, 30, 22, 20),
#   0],
#  ['hanj****',
#   '이 영화도 말이안된다고 평점을 깍은건가? 만약그런사람들이라면 평생영화를 보지말아라',
#   '10',
#   '2',
#   '1',
#   datetime.datetime(2015, 6, 7, 10, 1),
#   0],
#  ['아이샤(z2cl****)',
#   '애니메이션의 감동을 못 따라가고 걍 흔하디 흔한 아동용 모험영화가 되버림.',
#   '1',
#   '3',
#   '2',
#   datetime.datetime(2017, 4, 3, 1, 6),
#   0],
#  ['Fresh Meat(shba****)',
#   '이상한  이상하다..  이상해  뭔가  이상해',
#   '6',
#   '3',
#   '2',
#   datetime.datetime(2015, 8, 9, 2, 39),
#   0],
#  ['엠쿤(fubu****)',
#   '팀 버튼에게 정말 실망이였다.',
#   '1',
#   '4',
#   '3',
#   datetime.datetime(2016, 5, 10, 9, 33),
#   0],
#  ['cnjs****',
#   '독특한 캐릭터와 몽환적인 배경까지 좋았으나 마무리로 뒷받침해줄 스토리가 진부하고 허술했다',
#   '3',
#   '6',
#   '5',
#   datetime.datetime(2012, 1, 22, 4, 29),
#   0],
#  ['동훈(pssl****)',
#   '',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2020, 10, 27, 17, 10),
#   0],
#  ['bea(beau****)',
#   '',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 10, 1, 17, 9),
#   0],
#  ['세빈(sebi****)',
#   '강추책이랑 내용 거의 달라요진짜 재밌어요!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 10, 1, 15, 50),
#   0],
#  ['박예진(apin****)',
#   '시간가는 줄 모르고 재밌게 봤어요',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 9, 20, 19, 59),
#   0],
#  ['dbwl****',
#   '예전에 봤을때도 재미있었지만  요즘나오는 실사영화들이 원작 따라하기만 바쁜걸 보면 예전에 나왔는데도 예쁘고 아름다운 색상에 캐릭터들 원작에서 조금 비튼 스토리까지  충분히 재밌다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 9, 9, 21, 38),
#   0],
#  ['아이엠그루트(ysj0****)',
#   '',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 9, 4, 20, 3),
#   0],
#  ['백지승(bjsj****)',
#   '오래도록 기억에 남을영화♡',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 9, 3, 4, 24),
#   0],
#  ['정민(jung****)',
#   '',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 8, 17, 23, 32),
#   0],
#  ['혜빈(ansg****)',
#   '',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 8, 16, 23, 55),
#   0],
#  ['송주형(thdw****)',
#   '충무로는 흉내도 못내는 영화를 10년전에 만들었는데 전개가 부실하다... 케릭터의 매력이 없다는 둥.. 눈만 오지게 높네 이러니 반도 , 염력 이딴영화밖에 안나오지 ㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 7, 19, 11, 43),
#   0],
#  ['namtaegf(taem****)',
#   '',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 7, 13, 3, 13),
#   0],
#  ['dah(daha****)',
#   '꼭 보세요',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2020, 6, 20, 1, 21),
#   0],
#  ['지수에오(7hia****)',
#   '좀 지루함 모자장수춤출때 신박해서 잠은깼다!',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2020, 6, 15, 22, 56),
#   0],
#  ['ph57****',
#   '지루함없이 재밌게봤어요',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2015, 2, 19, 13, 55),
#   0],
#  ['페비(00fe****)',
#   '모자장수 존좋...ㅠㅠㅠㅠ진짜 흥미유발하느 ㄴ영화임',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2015, 2, 13, 13, 9),
#   0],
#  ['이예은(want****)',
#   '재밌다. 근데  이건  거울 나라의  앨리슨데',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2015, 2, 7, 21, 35),
#   0],
#  ['뎨헷(buti****)',
#   '조니뎁ㅜㅜ♥마지막에 용물리치는거짱 흰색여왕도이뻐ㅓ 진짜 10대들이보면딱좋을것같네요',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2015, 1, 21, 17, 53),
#   0],
#  ['belle200(ekdh****)',
#   '진짜 재밋게봤어요!!꿈속에 있는 것같은 영화',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2015, 1, 11, 12, 59),
#   0],
#  ['아래향(arae****)',
#   '이상한 나라의  앨리스  또   했으면  좋겠어요재미있더라구요.저요  1967년1월21일[양력]생일  입니다^^',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2015, 1, 11, 12, 22),
#   0],
#  ['별빛기도(1004****)',
#   '나는 희망한다. 나의 꿈을... 영화는 나에게 알게해줬다! 나의 마음속에 담겨져 있는 나의 마음을...',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2015, 1, 7, 5, 23),
#   0],
#  ['hyeseong(kang****)',
#   '정말로 이영화는 팀버튼 감독님 이시기에 가능하고 정말 재미있었다!!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2015, 1, 5, 17, 58),
#   0],
#  ['넌내꺼중에최고(daum****)',
#   '이거를 저는 5번은 본거같아요ㅠ내용 재밌어요 신비롭고 새로운게 진짜 한시도 졸릴틈이 없고..솔직히 몇번은 모자장수(조니뎁)볼려곸 조니뎁이란 분한테 관심은 없었는데 모자장수를 보고 반했다죠//진짜 재밌는데 평점이 7점...',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2015, 1, 4, 11, 24),
#   0],
#  ['luli****',
#   '다시 한번, 내 삶을 돌아보게 만들었다.',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2014, 12, 24, 15, 26),
#   0],
#  ['홍주(ghdw****)',
#   '글쎄... 너무 큰 기대를 하고 본 건가',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2014, 12, 12, 21, 2),
#   0],
#  ['oo(whdd****)',
#   '영상미 장난아닌 영화!! 보는 내내 흥미로움과 호기심이 가득차서 눈을 뗄수가 없었다! 동심을 찾고 싶다거나~ 심심할 때 보면 너무 좋은 영화~~ 티비에서 찌끔 보다가 나중에 다시봐야지 하고 이제야 봤는데 보길 정말 ...',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 12, 10, 17, 11),
#   0],
#  ['O(jmin****)',
#   '제가 좋아하는영화중 진짜찐짜좋아하는영화... :)',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 12, 9, 20, 58),
#   0],
#  ['꼬깽이(rhru****)',
#   '굿!!!ㅋㅋㅋㅋ훗ㅎ',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2014, 12, 7, 16, 45),
#   0],
# ...
#   0],
#  ['sooa****',
#   '역시 내가 가장 존경하는\n팀버튼 그의 상상력\n하지만 그게 끝 \n이상한 팀버튼의 앨리스',
#   '5',
#   '0',
#   '0',
#   datetime.datetime(2011, 3, 8, 4, 57),
#   0],
#  ['qojd****',
#   '너무 재밌었어요~^^ 한번 봐보세요~',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 3, 7, 16, 40),
#   0],
#  ['pela****',
#   '팀버튼 이름 석자의 기대치엔 지나치게 식상한 이야기, 관객과의 호흡에 실패하다.',
#   '5',
#   '0',
#   '0',
#   datetime.datetime(2011, 3, 7, 16, 36),
#   0],
#  ['ppt9****', '재밌음', '10', '0', '0', datetime.datetime(2011, 3, 6, 16, 14), 0],
#  ['puri****',
#   '완전 재밌었어요!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 3, 5, 21, 54),
#   0],
#  ['hari****',
#   '이래서 영화는 직접 봐야한다. 평점 믿지말고...개인차가 있잖아. 난 좋던데!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 3, 3, 12, 32),
#   0],
#  ['audd****',
#   '완전~ 재밋음 추천!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 3, 2, 13, 43),
#   0],
#  ['1494****',
#   '이영화보고싶은데 .......어떻게보는지모르겠어요',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 3, 1, 21, 18),
#   0],
#  ['sjzz****',
#   '대박잼써~',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 28, 19, 14),
#   0],
#  ['cds2****',
#   '재밌습니닷 >_<~♥>',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 28, 18, 39),
#   0],
#  ['jk12****',
#   '완존 재밋써여!! 이 댓글 보신분들은 꼭 한번 보시길 바래요!! 진심이에요~ ^.^*',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 26, 21, 17),
#   0],
#  ['7777****',
#   '우와~~~~~~~~~~~~~진짜재밍엉~~~~~~~~~~~~~~~~~~~',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 25, 10, 28),
#   0],
#  ['dear****',
#   '진짜 재밌어요~~~~~~ㅎㅎ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 24, 15, 42),
#   0],
#  ['sksm****',
#   '잼긴재밋음 ㅇㅁㅇ',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 23, 18, 8),
#   0],
#  ['sjle****',
#   '대박 잼써',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 21, 20, 40),
#   0],
#  ['bdwo****',
#   '이사람들이 영화스토리만보지말고 영화속에서 진정 말하는걸 알아야지',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 21, 8, 59),
#   0],
#  ['sou8****',
#   '뭐지................',
#   '4',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 20, 21, 28),
#   0],
#  ['kimg****',
#   '이야기 구성이 미흡한 점이 살짝 아쉽지만, 영상미로 인한 판타지는 느낄 수 있었다',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 20, 15, 45),
#   0],
#  ['icn2****',
#   '이상하지만 이상하지않은 앨리스의 이야기 *',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 20, 14, 42),
#   0],
#  ['lasp****',
#   '모자 장수 쵝오!!!!!!!!!!!!!!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 19, 15, 16),
#   0],
#  ['yj10****',
#   '개성있는 캐릭터들',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 19, 11, 12),
#   0],
#  ['tops****',
#   '붉은여왕에게 영광을!',
#   '5',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 19, 6, 54),
#   0],
#  ['2723****',
#   'ㅋㅋㅋ그냥볼만했음.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 16, 18, 24),
#   0],
#  ['tngu****',
#   '이거 진짜진짜 잼 있다. 그리고 진짜 주인공은 하얀나라에 공주닼ㅋㅋㅋ...........',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 14, 21, 11),
#   0],
#  ['andr****',
#   '솔직히 진짜 주인공은 앨리스가 아니라 빨간여왕이다',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 14, 8, 6),
#   0],
#  ['befr****',
#   '이영화는 사탄주의 영화입니다 속지마세요',
#   '4',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 12, 14, 52),
#   0],
#  ['hanm****',
#   '우왕 첨으로 로긘하고 평점줍니다! 재밌어여>.<일단보셈>!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 12, 6, 14),
#   0],
#  ['gusd****',
#   '재미있다!!♣',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 10, 18, 41),
#   0],
#  ['dhra****',
#   '↓얘 조니뎁 안티인가봄ㅋ다 이런식으로 평점ㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 9, 14, 27),
#   0],
#  ['ssor****',
#   '색다른엘리스 엘리스배우매력적이군요1',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 8, 22, 57),
#   0],
#  ['kid4****',
#   '판타지적이라 좋아요....^^',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 7, 19, 24),
#   0],
#  ['wdf1****',
#   '재밌어요!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 6, 19, 36),
#   0],
#  ['aasd****',
#   '진짜 대박 재미있어요!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 6, 18, 15),
#   0],
#  ['oys0****',
#   '최고의 영화!!! 강추입니다!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 2, 1, 20, 52),
#   0],
#  ['dun0****',
#   '완전재밌어요',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 31, 12, 40),
#   0],
#  ['a109****',
#   '개인적으로 내용이 우선시되어야 재미있는데.그래픽만 멋있음',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 31, 6, 51),
#   0],
#  ['dool****', '재미', '9', '0', '0', datetime.datetime(2011, 1, 30, 11, 28), 0],
#  ['tlst****',
#   '동심으로 돌아간 기분으로 봤어염 ㅋㅋㅋ',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 29, 15, 36),
#   0],
#  ['wo58****',
#   '재미있다 진짜로',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 29, 12, 12),
#   0],
#  ['mung****', '재밌다', '8', '0', '0', datetime.datetime(2011, 1, 28, 22, 21), 0],
#  ['rilr****',
#   '화려한 화면 지루한 진행 기대를 하지 말것 그럼 볼만할지도',
#   '5',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 26, 23, 1),
#   0],
#  ['tpsk****',
#   '무난하게 봤는데. 평점 보기전에 보길 잘한것 같군..',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 26, 22, 11),
#   0],
#  ['wbsl****',
#   '영화를보고 모자장수라는 캐릭터에 푹빠졌어요!전 개인적으로 추천하고 싶은 영화1위!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 25, 20, 49),
#   0],
#  ['itsk****',
#   '팀버튼의 이름때문에 기대가 너무 높앗나..하지만 역시나 팀버튼만이 할수잇는영상미.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 25, 16, 58),
#   0],
#  ['choc****',
#   '동화책 보기를 권장한다.',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 24, 19, 32),
#   0],
#  ['vlzm****',
#   '마지막이 좀 ㅋㅋ',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 23, 21, 30),
#   0],
#  ['gkdu****',
#   '꽤 괜찮은 영환데 .... 좀 지루할수도 있는 영화에요 특별히 엄청난 반전도 없구요',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 20, 14, 37),
#   0],
#  ['kmgd****',
#   'ㅎㅎㅎㅎㅎㅎㅎㅎㅎ와저사람얼굴조니무서웡 무서워성 깍아야징 ! !',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 20, 14, 31),
#   0],
#  ['psyp****',
#   '중간에 쪼금 지겨워서 반깍아요^_^재밌긴 재밌네요',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 20, 14, 29),
#   0],
#  ['wer0****',
#   '기대보다 덜해서 1점 깎였지만.. 그래도 재밌는 영화.',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 20, 13, 40),
#   0],
#  ['eunh****',
#   '재미있게 봤지만 1점을 깎은것은 마음에 다 찰 정도의 무언가가 와닺지 않았기 때문',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 18, 21, 9),
#   0],
#  ['debb****',
#   '재미있다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 17, 21, 22),
#   0],
#  ['dkgu****',
#   '재밋게 잘봤는데전,,',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 16, 16, 35),
#   0],
#  ['lil4****',
#   '재밌어요~^ㅂ^',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 16, 15, 46),
#   0],
#  ['tmdr****',
#   '난꽤 재밌게 본것같은데>ㅋㅋㅋ꽤 귀여운 영화인듯ㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 15, 15, 48),
#   0],
#  ['ques****',
#   '그림만 예쁘다.  팀버튼영화 좋아하는데 이영화까지 좋아하기엔 무리',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 14, 8, 26),
#   0],
#  ['nice****',
#   '이것도아니고,저것도아니고.ㅋ 동화가좋아서갔느넫..실망.ㅜㅜ 괜히 쓰리디로봣다..',
#   '4',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 12, 21, 32),
#   0],
#  ['thdl****',
#   '조니뎁 연기 완전 잘하네ㅋ꼭 보시길..!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 12, 16, 38),
#   0],
#  ['glee****',
#   'ㅎㅎㅎㅎㅎㅎㅎㅎㅎ 귀엽다 ㅎㅎㅎㅎㅎ 나중에 또 보고 싶당 ㅎㅎ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 11, 23, 37),
#   0],
#  ['cks2****',
#   '재밌는데?!?!배경들도 좋고 상상력도 조~코ㅋㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 11, 3, 7),
#   0],
#  ['cola****',
#   '평점보다 재미있음',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 10, 18, 43),
#   0],
#  ['cart****',
#   '색감 멋있는거랑 캐릭터들 재밌는것 만으로 볼만한 가치가 있음ㅋ',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 10, 17, 41),
#   0],
#  ['gusd****',
#   '재밌었어요 동화같은 영화를 좋아하는 분들이 보면 재밌게 볼것 같네요',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 9, 11, 47),
#   0],
#  ['yunj****',
#   '잔인 한거......................나와서 별로임(팬은 죄송)',
#   '4',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 8, 12, 15),
#   0],
#  ['gjth****',
#   '눈깔이랑 혀짜르는건 어린애들 보는데 그렇지 않나......',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 7, 18, 57),
#   0],
#  ['wndd****',
#   '재밌네 ㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 7, 4, 12),
#   0],
#  ['apsa****',
#   '완젼재밌었는뎀!!!!!!!!!꺄악!!!!!!!!!난 재밌었어요.....',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 6, 22, 43),
#   0],
#  ['dhdb****',
#   '윽!!!완전 미친 모자장수 얼굴 무섭당!~ 상상력이 아주..',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 5, 21, 19),
#   0],
#  ['kth9****',
#   '전체관람가라서 유치한건 봐준다만 눈알은 못봐주겠다.',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 3, 14, 57),
#   0],
#  ['erhe****',
#   '비쥬얼적, 캐릭터적 상상력은 좋다만',
#   '5',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 2, 23, 10),
#   0],
#  ['smkc****',
#   '전체관람가입니다. 유치할 수도 있는 걸 가지고 뭘 그럽니까',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2011, 1, 2, 22, 56),
#   0],
#  ['kdh2****',
#   '이 영화가 흥행한 이유는 조니뎁과 팀버튼이 있었기 때문.',
#   '5',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 31, 11, 15),
#   0],
#  ['inye****',
#   '재밌는 줄 알았지 .. 좀 훈훈한면도 있지만 극장에서 봤다면 보다가 잠들었을 듯?',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 31, 11, 14),
#   0],
#  ['kent****',
#   '팀버튼과 조니뎁이란 네임벨류만으로 성공한 영화는 아니었을지.',
#   '5',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 31, 9, 15),
#   0],
#  ['tofh****',
#   '3D로 보니 대박 재밌음 !!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 30, 21, 10),
#   0],
#  ['hulk****',
#   '좀시시하다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 29, 15, 40),
#   0],
#  ['gpwn****',
#   '재밋었어요ㅋㅋㅋㅋㅋㅋ3d로봣으면재밋엇을텐데',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 29, 13, 45),
#   0],
#  ['tmdb****',
#   '팀버튼 만세!~~~',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 27, 16, 32),
#   0],
#  ['nora****',
#   '나도 조니뎁과 함께 날뜩한 칼을 들고 으쓱쿵짝 춤을 추고 싶어 졌다 ^^',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 27, 15, 0),
#   0],
#  ['kdy5****',
#   '책과 비교하며 보았다. 재미있었다.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 26, 0, 45),
#   0],
#  ['haei****',
#   '책보다 더 신선한 영화',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 25, 16, 1),
#   0],
#  ['happ****',
#   '시간잘감 매력있음',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 24, 23, 19),
#   0],
#  ['tjsw****',
#   '앨리스의 멋진 모험. 역시나 조니뎁은 팔색조 매력남',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 24, 16, 48),
#   0],
#  ['ths8****',
#   '모자장수 춤 멋지더라',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 24, 10, 17),
#   0],
#  ['pkju****',
#   '동화와는 색다른 재미가 있다',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 24, 9, 53),
#   0],
#  ['lees****',
#   '화려한 색감은 만점! 그러나 스토린 지루함~ 글픽도 좀 엉성~ 가위손이 최고였다!',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 23, 13, 47),
#   0],
#  ['chj4****',
#   '팀버튼은 사람들을 어린시절로 돌아가게하는 능력이있다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 23, 0, 8),
#   0],
#  ['wooj****',
#   '뒤로갈수록ㅜㅜ',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 20, 14, 50),
#   0],
#  ['ksyk****',
#   '그럭저럭. 책을 읽는게 낫다',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 20, 0, 24),
#   0],
#  ['wlfa****',
#   '팀 버튼의 실수. 이상한 팀 버튼의 동화세계.',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 19, 18, 13),
#   0],
#  ['gudw****',
#   '평점보고 영화관가서 안본게 후회ㅡㅡ진짜 레알ㅠㅠㅠ모자장수 하얀여왕ㅠㅠ으으',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 18, 15, 7),
#   0],
#  ['dest****',
#   '멋진 판타지!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 14, 23, 6),
#   0],
#  ['biks****',
#   '이건뭐... 애들 장난도 아니고... ㅡ,.ㅡa',
#   '3',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 14, 9, 18),
#   0],
#  ['minj****',
#   '재밌네요 ^^캐릭터들도 웃기궁 ㅋㅋ모자장수짱',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 14, 7, 19),
#   0],
#  ['qkrw****',
#   '좋군..',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 13, 20, 9),
#   0],
#  ['babo****',
#   '3D로 봤으면 더 잼있었을듯.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 13, 18, 38),
#   0],
#  ['hyun****',
#   '엄청 재미있어요!^^',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 13, 18, 20),
#   0],
#  ['wndu****',
#   '앨리스잼잇네여',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 13, 16, 18),
#   0],
#  ['kbs7****',
#   '너무재밌고 좋네여',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 11, 22, 24),
#   0],
#  ['jssk****',
#   '스릴 넘치고 잼있어요!저 8달전인가?그떄 봣어요;',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 11, 17, 35),
#   0],
#  ['dlwn****',
#   '영화 정말 잘 봤습니다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 9, 17, 16),
#   0],
#  ['caca****',
#   '행복한 꿈.',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 8, 15, 33),
#   0],
#  ['p_ru****',
#   '솔직히 좀 지루하네요...',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 5, 21, 35),
#   0],
#  ['swes****',
#   '어떤 마음가짐으로 보냐에따라 틀린영화',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2010, 12, 4, 9, 54),
#   0],
#  ['wind****',
#   '약간은 유치한 내러티브지만 몰입도도 나쁘지않고 재미도 있다..',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 30, 22, 59),
#   0],
#  ['lipe****',
#   '아쉬움이 많지만 잘만들긴했다.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 28, 21, 8),
#   0],
#  ['zlat****',
#   '캐릭터들 보는재미에 푹 빠졌음 ㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 27, 2, 37),
#   0],
#  ['tori****',
#   '10억달러의 마음을 훔친 이유를 모르겠다.',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 26, 22, 47),
#   0],
#  ['sou0****',
#   '재밌긴한데 그냥 그랬어요...',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 24, 15, 47),
#   0],
#  ['duox****',
#   '아주 흥미진진했는데 나는ㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 24, 12, 1),
#   0],
#  ['bitl****',
#   '영화는 그런대로 볼만했으나, 팀버튼만의 색깔은 찾아볼수 없음',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 20, 17, 13),
#   0],
#  ['clar****',
#   '굿굿굿! 기대를 안하고 봐서 그런건지는 몰라도 난 좋았음! 모자장수짱ㅜ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 14, 0, 36),
#   0],
#  ['kej3****',
#   '짱!짱!!짱!!!!!!! 진짜 재밌음!! 예상보단재미가 없었지만 그래도 짱!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 13, 19, 47),
#   0],
#  ['qwer****',
#   '정말최고입니다 강추요',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 12, 22, 36),
#   0],
#  ['qkrd****',
#   '재미있어요 ㅋㅋㅋㅋㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 12, 19, 34),
#   0],
#  ['beli****',
#   '역시 죠니뎁-이상한 나라의 모자장수!',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 11, 3, 20),
#   0],
#  ['cje4****',
#   '재미있어요~',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 9, 17, 19),
#   0],
#  ['si2p****',
#   '팀버튼 색깔의 앨리스... <배트맨>만큼은 아니지만 볼만한 영화',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 8, 20, 55),
#   0],
#  ['akar****',
#   '평점이 낮아서 재미없나..싶었는데 안봤으면후회할 영화! 정말 재밌게봤다 ㅎㅎ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 8, 17, 21),
#   0],
#  ['seoh****',
#   '조니뎁의 신들린 연기가 돋보였다. 환상적인 영화.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 8, 0, 1),
#   0],
#  ['von3****',
#   '제가 본 영화중에서1위로잼잇음 2위가 해운대. 해운대도잼는데 평점낮음 이것처럼',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 7, 16, 13),
#   0],
#  ['cink****',
#   '팀 버튼.. 전성기가 지나버린 것 같다.. 이젠 평범한 영화를 만드는 평범한 감독..',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 5, 3, 34),
#   0],
#  ['0107****',
#   '괜찮았다 나도 모험이 떠나지고싶은 순수함이 솓아 오른다',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 3, 21, 52),
#   0],
#  ['kjm0****',
#   '역시 난 어리구나 이게 재밌는걸보니',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 3, 16, 1),
#   0],
#  ['cont****',
#   '팀 버튼의 명성에 비하면 조금 부족한 느낌.',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2010, 11, 2, 23, 44),
#   0],
#  ['wlgu****',
#   '또 다른 이상한나라의앨리스 를 보고 여러가지 깨닳은게 많다.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 31, 20, 24),
#   0],
#  ['3771****',
#   '표현은 좋은데 너무 재미없다...',
#   '5',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 30, 20, 46),
#   0],
#  ['dksw****',
#   '정말빠져드는영화.삶의자신감을회복할수있는영화',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 30, 12, 5),
#   0],
#  ['moff****',
#   '신기하긴한데 재미는 없음.',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 27, 13, 50),
#   0],
#  ['mddo****',
#   '팀 버튼이기에 만들 수 있는 영화. 하지만 조금 아쉽다.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 26, 4, 23),
#   0],
#  ['wire****',
#   '재밌다.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 24, 20, 34),
#   0],
#  ['pers****',
#   '디즈니 영화로서는 괜찮지만 팀버튼 작품으로서는 망했다',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 23, 8, 32),
#   0],
#  ['dohy****',
#   '별루 잼없어요',
#   '5',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 10, 8, 3),
#   0],
#  ['miso****',
#   '와우~!! 쩐다 쩔어 재미 팡팡',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 9, 14, 35),
#   0],
#  ['cand****',
#   '영국영어랑 미국영어랑 막섞여서 ㅋㅋㅋ',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 7, 14, 26),
#   0],
#  ['dhkd****',
#   '키스신은개뿔.재밋기만한데 ㅋㅋㅋㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 6, 16, 3),
#   0],
#  ['chae****',
#   '너무새롭고 신비한 영화였어요 몰입도도 높았고^^',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 6, 12, 57),
#   0],
#  ['nhj8****',
#   '키스신이 너무많아 애들한테는조금 그럴듯..',
#   '3',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 3, 16, 12),
#   0],
#  ['bril****',
#   '조니 뎁이 너무 사랑스러운.._+',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2010, 10, 2, 22, 5),
#   0],
#  ['resm****',
#   '때깔 하나 만큼은 정말 죽이는구나',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2010, 9, 30, 9, 28),
#   0],
#  ['kore****',
#   '엘리스 보는맛으로도 충분히 몰입가능',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 9, 30, 8, 19),
#   0],
#  ['love****',
#   '처음엔 뭔가 싶었는데 볼수록 괜찮더라구요 ^^',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2010, 9, 28, 16, 6),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                     0  ...  6
# 0       박해빈(phb5****)  ...  0
# 1       툴루즈(tull****)  ...  0
# 2       픽쳐콤(goms****)  ...  0
# 3     na010(na01****)  ...  0
# 4        토이(ikeu****)  ...  0
# ...               ...  ... ..
# 5795         lyj1****  ...  0
# 5796         banm****  ...  0
# 5797         9560****  ...  0
# 5798         simk****  ...  0
# 5799         hyes****  ...  0
#
# [5800 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#              nickname  ... watch_movie
# 0       박해빈(phb5****)  ...           0
# 1       툴루즈(tull****)  ...           0
# 2       픽쳐콤(goms****)  ...           0
# 3     na010(na01****)  ...           0
# 4        토이(ikeu****)  ...           0
# ...               ...  ...         ...
# 5795         lyj1****  ...           0
# 5796         banm****  ...           0
# 5797         9560****  ...           0
# 5798         simk****  ...           0
# 5799         hyes****  ...           0
#
# [5800 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
